# %%
# For now, I'm just focusing on delta hedging. After that is done, we make a system of equations
# to set delta and vega to 0 and solve with np.linalg.solve() (see examples/ex6sol for reference).
# %pip install pyfinance
# %pip install py_vollib
# %pip install pandas
# %pip install matplotlib

import pandas as pd
from pyfinance.options import BSM
from datetime import datetime, timedelta
import py_vollib
from py_vollib.black_scholes.implied_volatility import implied_volatility
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.pyplot as plt

df = pd.read_csv("../data/apple.csv")
df = df.drop(["Unnamed: 0"], axis=1)
df['date'] = pd.to_datetime(df['Date'])
df['T'] = (pd.to_datetime('2024-01-19') - df['date']).dt.days / 252 # T = time to expiration in years, 252 trading days
df = df.drop(["date"], axis=1)
df.head()

#interest rate data
df2 = pd.read_csv('../data/daily-treasury-rates.csv')
df2 = df2[['Date', '13 WEEKS COUPON EQUIVALENT']]
df2['Date'] = pd.to_datetime(df2['Date'], format='%m/%d/%Y')
df2['Date'] = df2['Date'].dt.strftime('%Y-%m-%d')
df2 = df2[df2['Date'] >= '2023-08-21']
df2['13 WEEKS COUPON EQUIVALENT'] = df2['13 WEEKS COUPON EQUIVALENT'] / 100
df_result = pd.merge(df, df2, on='Date', how='left')
df_result.rename({"13 WEEKS COUPON EQUIVALENT": "Interest rate"}, axis="columns", inplace=True)
df_result['Interest rate'].fillna(df_result['Interest rate'].median(), inplace=True)
df_result.head()
# Out:
# Requirement already satisfied: pyfinance in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: matplotlib in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (3.8.2)
# Requirement already satisfied: pandas>=0.20 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (2.1.4)
# Requirement already satisfied: requests in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (2.31.0)
# Requirement already satisfied: numpy in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (1.26.2)
# Requirement already satisfied: beautifulsoup4 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (4.12.2)
# Requirement already satisfied: seaborn in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (0.13.0)
# Requirement already satisfied: statsmodels in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (0.14.1)
# Requirement already satisfied: xlrd in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (2.0.1)
# Requirement already satisfied: scikit-learn in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (1.3.2)
# Requirement already satisfied: scipy in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (1.11.4)
# Requirement already satisfied: pandas-datareader in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (0.10.0)
# Requirement already satisfied: xmltodict in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pyfinance) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas>=0.20->pyfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas>=0.20->pyfinance) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas>=0.20->pyfinance) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.20->pyfinance) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from beautifulsoup4->pyfinance) (2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (10.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (4.47.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (6.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (23.2)
# Requirement already satisfied: cycler>=0.10 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib->pyfinance) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pyfinance) (3.17.0)
# Requirement already satisfied: lxml in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas-datareader->pyfinance) (4.9.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from requests->pyfinance) (2023.11.17)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from requests->pyfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from requests->pyfinance) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from requests->pyfinance) (3.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from scikit-learn->pyfinance) (3.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from scikit-learn->pyfinance) (1.3.2)
# Requirement already satisfied: patsy>=0.5.4 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from statsmodels->pyfinance) (0.5.5)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/aleksi/koodaus/hedging-simulation/venv/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: py_vollib in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: pandas in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from py_vollib) (2.1.4)
# Requirement already satisfied: py-lets-be-rational in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from py_vollib) (1.0.1)
# Requirement already satisfied: simplejson in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from py_vollib) (3.19.2)
# Requirement already satisfied: numpy in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from py_vollib) (1.26.2)
# Requirement already satisfied: scipy in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from py_vollib) (1.11.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas->py_vollib) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas->py_vollib) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas->py_vollib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->py_vollib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/aleksi/koodaus/hedging-simulation/venv/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/aleksi/koodaus/hedging-simulation/venv/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: pillow>=8 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 23.3.2 is available.
# You should consider upgrading via the '/Users/aleksi/koodaus/hedging-simulation/venv/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
#          Date  Underlying   C170   C175   C180   C185  C190  P170  P175  \
# 0  2023-08-21      175.84  16.40  13.27  10.30   7.85  5.91  6.81  8.65
# 1  2023-08-22      177.23  17.50  14.10  11.10   8.51  6.34  6.26  8.10
# 2  2023-08-23      181.12  20.20  16.65  13.45  10.55  8.08  5.25  6.71
# 3  2023-08-24      176.38  16.97  13.75  10.80   8.35  6.25  6.85  8.62
# 4  2023-08-25      178.61  18.50  15.15  11.85   9.19  6.90  5.90  7.50
#
#     P180   P185   P190         T  Interest rate
# 0  10.85  13.35  16.50  0.599206         0.0546
# 1  10.10  12.75  15.50  0.595238         0.0546
# 2   8.50  10.70  13.33  0.591270         0.0546
# 3  10.75  13.35  16.60  0.587302         0.0547
# 4   9.50  11.90  14.81  0.583333         0.0550

# %% [markdown]
# The delta measures the rate of change of the security wrt. to the price of the underlying. Thus, the delta of the stock is one.
# Vega measures the rate of change of the security wrt. to the volatility of the underlying. Again, the vega of the stock is one. In delta hedging, we short the option and hold a dynamically adjusted amount of the risky asset to eliminate the risk.

# %% [markdown]
# Next, calculate the hedge with 2 portfolios: OP and RE. OP has a long call and RE has a short amount of the underlying asset (here, $AAPL). We want P = OP + RE to be neutral to small changes in the underlying price.

# %% [markdown]
# # Delta hedging a single option

# %%
# The code below is bit of spaghetti code and could use some significant improvements when time available
# TODO:
# - give all necessary information (option amounts, strikes, option types, etc.) as a parameter
# - handle printing in its own function
# - save and show the data in a clearer format
def delta_hedge(call_option_prices, freq, colname, costs = 0):
    # call_options_prices is a df, freq is hedging frequency (e.g. 30 = once a month), colname is e.g. "C170", costs = trading costs
    # This has been looked up from the internet for Apple stock option
    option_amount = 1000
    interest_rate = call_option_prices.iloc[0]['Interest rate']
    option_type = 'call' if colname[0] == "C" else "put"
    stock_price = call_option_prices.iloc[0]['Underlying']
    option_price = call_option_prices.iloc[0][colname]
    strike = int(colname[1:])
    time_to_maturity = call_option_prices.iloc[0]['T']
    volatility = implied_volatility(price=option_price, S=stock_price, K=strike, t=time_to_maturity, r=interest_rate, flag=option_type[0])
    
    # Initial stuff at t = 0
    bsm_obj = BSM(kind=option_type, S0=stock_price, K=strike, T=time_to_maturity, r=interest_rate, sigma=volatility)
    OP = bsm_obj.value() * option_amount # Value of the option according to BSM from the assignment
    delta = bsm_obj.delta()
    RE = - delta * stock_price * option_amount # Replicating portfolio from the assignment
    amount = -(delta * option_amount)

    print("================ Initial values: =================")
    print("Date:", call_option_prices.iloc[0]['Date'])
    print(f"Value of single call option (for {option_amount} stocks) according to BSM: ", round(OP, 2))
    print("Value of the short position according to BSM: ", round(RE, 2))
    print("# of stocks short: ", round(amount, 2))
    print("Delta of the option according to BSM: ", round(delta, 2))
    print('==================================================')
    print('\n')

    # We will keep track of the changes in the portfolios
    # This corresponds to the do we make loss or profit in hedging
    total_mean_squared_error = []
    portfolio_values = [OP+RE] # add initial portfolio value to the list
    OPs = [OP]
    REs = [RE] # we save these for plotting purposes, not used in this function

    transact_costs = 0 # total transaction costs carry and decrease the value of portfolio
    
    # next we calculate changes in OP and RE and let A_0 = d OP - d RE
    # Hedge as long as there are dates in the dataframe
    for i in range(1, len(call_option_prices)-1):
        new_OP = call_option_prices[colname][i] * option_amount
        new_RE = - delta * call_option_prices['Underlying'][i] * option_amount
        d_OP = new_OP - OP
        d_RE = new_RE - RE
        a_0 = d_OP + d_RE # We would want this to be 0; IMMUNE TO CHANGES

        total_mean_squared_error.append(a_0**2)
        portfolio_values.append(OP+RE+transact_costs)
        OPs.append(new_OP)
        REs.append(new_RE)

        print('=================================================')
        print("Date:", call_option_prices['Date'][i])
        print(f"Value of single call option (for {option_amount} stocks) according to BSM: ", round(new_OP, 2))
        print("Value of the new short position according to BSM: ", round(new_RE, 2))
        print("# of stocks short: ", round(amount, 2))
        print("Delta of the option according to BSM: ", round(delta, 2))
        print("Total error, difference of the portfolios: ", round(a_0, 2))
        print('=================================================')
        print('\n')

        OP = new_OP
        RE = new_RE

        # Rehedging happens here
        # every second day, t2, t4, t6, so on..
        # Change the modulo for different intervals, 1 = every day, 30 = every month and so on
        if i % freq == 0:
            # Delta and volatility will be updated when we rehedge
            # As time goes by, the stock price moves/changes. This will affect the delta of the stock option, delta of the underlying is always 1
            # In a real world scenario this hedging costs money, and will be simulated if we have time also in this
            volatility = implied_volatility(price=call_option_prices[colname][i], S=call_option_prices['Underlying'][i], K=strike, t=call_option_prices['T'][i], r=call_option_prices['Interest rate'][i], flag=option_type[0])
            delta = BSM(kind=option_type, S0=call_option_prices['Underlying'][i], K=strike, T=call_option_prices['T'][i], r=call_option_prices['Interest rate'][i], sigma=volatility).delta()
            #delta = 0.7
            
            print('=============== REHEDGE =========================')
            print("Rehedging date:", call_option_prices['Date'][i])
            print("Delta updated, new delta is:", round(delta, 2))
            print("Volatility updated, new implied volatility is:", round(volatility, 5))
            print('To delta-hedge a single long call option, we need to readjust the RE:')

            # We have to solve a linear equation, where the delta of the portfolio is zero
            # And we have to readjust by shorting delta amount of the underlying
            # Delta of the underlying is always 1
            RE = -(delta * call_option_prices['Underlying'][i] * option_amount)
            # or just the amount
            amount = -(delta * option_amount)

            if amount > 0:
                print('Readjusting replicating portoflio RE, amount options to hold to balance the portfolio: ', round(amount))
                transact_costs -= costs*100000 #include trading costs in portfolio value
            elif amount < 0:
                print('Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio: ', round(-amount))
                transact_costs -= costs*100000
            else:
                print('Portfolio is in balance, no need for readjustment')
            print('Long position is: ', round(OP))
            print('=============== REHEDGE ENDS ====================')
            print('\n')

    total_error = sum(total_mean_squared_error) - total_mean_squared_error[-1] # Sum 1 to n-1 of the MSEs
    total_error *= (1 / (len(total_mean_squared_error)-1) )
    print('========== Total Mean Squared Error ==============')
    print("The total mean squared error is : ", total_error)
    print('==================================================')

    return total_mean_squared_error, total_error, portfolio_values, OPs, REs # return daily errors and the total error for plotting purposes

# %%
hedging_frequencies = [1, 10, 30]
plt.figure(figsize=(10, 6))
for freq in hedging_frequencies:
    total_mean_squared_error, total_error, portfolio_values, OPs, REs = delta_hedge(df_result, freq, "C170")
    plt.plot(total_mean_squared_error, label=f'Hedging Frequency: {freq} days')

plt.xlabel('Days')
plt.ylabel('Daily Error')
plt.title('Daily Error vs Hedging Frequency')
plt.legend()
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of single call option (for 1000 stocks) according to BSM:  16400.0
# Value of the short position according to BSM:  -123781.57
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of single call option (for 1000 stocks) according to BSM:  17500.0
# Value of the new short position according to BSM:  -124760.05
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  121.52
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-22
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18856
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  720
# Long position is:  17500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-23
# Value of single call option (for 1000 stocks) according to BSM:  20200.0
# Value of the new short position according to BSM:  -130381.38
# # of stocks short:  -719.86
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -100.26
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18519
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  20200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of single call option (for 1000 stocks) according to BSM:  16970.0
# Value of the new short position according to BSM:  -136027.33
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  425.57
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-24
# Delta updated, new delta is: 0.71
# Volatility updated, new implied volatility is: 0.19236
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  706
# Long position is:  16970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-25
# Value of single call option (for 1000 stocks) according to BSM:  18500.0
# Value of the new short position according to BSM:  -126086.99
# # of stocks short:  -705.93
# Delta of the option according to BSM:  0.71
# Total error, difference of the portfolios:  -44.23
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19141
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  18500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of single call option (for 1000 stocks) according to BSM:  19400.0
# Value of the new short position according to BSM:  -132587.64
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -262.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-28
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.18867
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  19400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-29
# Value of single call option (for 1000 stocks) according to BSM:  22030.0
# Value of the new short position according to BSM:  -139560.7
# # of stocks short:  -757.99
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -348.89
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Delta updated, new delta is: 0.81
# Volatility updated, new implied volatility is: 0.17866
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  814
# Long position is:  22030
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of single call option (for 1000 stocks) according to BSM:  24620.0
# Value of the new short position according to BSM:  -152691.1
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  -282.37
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-30
# Delta updated, new delta is: 0.86
# Volatility updated, new implied volatility is: 0.16967
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  860
# Long position is:  24620
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-31
# Value of single call option (for 1000 stocks) according to BSM:  24970.0
# Value of the new short position according to BSM:  -161626.05
# # of stocks short:  -860.31
# Delta of the option according to BSM:  0.86
# Total error, difference of the portfolios:  160.73
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Delta updated, new delta is: 0.85
# Volatility updated, new implied volatility is: 0.1763
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  855
# Long position is:  24970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of single call option (for 1000 stocks) according to BSM:  26000.0
# Value of the new short position according to BSM:  -161911.77
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  -328.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-01
# Delta updated, new delta is: 0.88
# Volatility updated, new implied volatility is: 0.16683
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  881
# Long position is:  26000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-05
# Value of single call option (for 1000 stocks) according to BSM:  26350.0
# Value of the new short position according to BSM:  -167038.24
# # of stocks short:  -880.54
# Delta of the option according to BSM:  0.88
# Total error, difference of the portfolios:  138.67
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.17788
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  871
# Long position is:  26350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -159298.89
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  313.51
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.18197
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  798
# Long position is:  20750
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-07
# Value of single call option (for 1000 stocks) according to BSM:  17000.0
# Value of the new short position according to BSM:  -141776.39
# # of stocks short:  -798.47
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  521.82
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.19135
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  722
# Long position is:  17000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -128697.76
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -347.82
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-08
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18426
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  737
# Long position is:  17100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-11
# Value of single call option (for 1000 stocks) according to BSM:  17600.0
# Value of the new short position according to BSM:  -132161.45
# # of stocks short:  -736.85
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -369.48
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17875
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  759
# Long position is:  17600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -133742.85
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -428.66
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-12
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.16839
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  724
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-13
# Value of single call option (for 1000 stocks) according to BSM:  13570.0
# Value of the new short position according to BSM:  -126148.89
# # of stocks short:  -724.12
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  233.41
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Delta updated, new delta is: 0.69
# Volatility updated, new implied volatility is: 0.1742
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  685
# Long position is:  13570
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of single call option (for 1000 stocks) according to BSM:  14450.0
# Value of the new short position according to BSM:  -120455.18
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  -168.69
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-14
# Delta updated, new delta is: 0.71
# Volatility updated, new implied volatility is: 0.17105
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  713
# Long position is:  14450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-15
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -124724.81
# # of stocks short:  -712.67
# Delta of the option according to BSM:  0.71
# Total error, difference of the portfolios:  170.25
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.176
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  697
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of single call option (for 1000 stocks) according to BSM:  16080.0
# Value of the new short position according to BSM:  -124044.6
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -83.11
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-18
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.17639
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  742
# Long position is:  16080
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-19
# Value of single call option (for 1000 stocks) according to BSM:  16870.0
# Value of the new short position according to BSM:  -132901.43
# # of stocks short:  -742.18
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -26.39
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17687
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  16870
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of single call option (for 1000 stocks) according to BSM:  14520.0
# Value of the new short position according to BSM:  -132978.12
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  362.76
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-20
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18425
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  698
# Long position is:  14520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-21
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -121438.85
# # of stocks short:  -698.21
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  89.2
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18715
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  671
# Long position is:  13520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -117365.34
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  2.54
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-22
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.18852
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -120445.85
# # of stocks short:  -684.04
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -132.41
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18878
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  704
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121089.25
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  601.18
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-26
# Delta updated, new delta is: 0.63
# Volatility updated, new implied volatility is: 0.20085
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  632
# Long position is:  12550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -107721.9
# # of stocks short:  -632.06
# Delta of the option according to BSM:  0.63
# Total error, difference of the portfolios:  -332.95
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.1942
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  608
# Long position is:  11250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -103847.0
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -108.18
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-28
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.19322
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  613
# Long position is:  11300
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -104870.95
# # of stocks short:  -612.53
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -118.51
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Delta updated, new delta is: 0.62
# Volatility updated, new implied volatility is: 0.19178
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  622
# Long position is:  11500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -108017.13
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  -629.07
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-02
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.1792
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  672
# Long position is:  12450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -115904.92
# # of stocks short:  -672.3
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  737.61
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-04
# Delta updated, new delta is: 0.66
# Volatility updated, new implied volatility is: 0.19688
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  660
# Long position is:  13000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -115425.19
# # of stocks short:  -659.91
# Delta of the option according to BSM:  0.66
# Total error, difference of the portfolios:  -274.89
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.19126
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -121349.24
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -113.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-06
# Delta updated, new delta is: 0.73
# Volatility updated, new implied volatility is: 0.18819
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  727
# Long position is:  15200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -130199.15
# # of stocks short:  -727.41
# Delta of the option according to BSM:  0.73
# Total error, difference of the portfolios:  -91.12
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Delta updated, new delta is: 0.75
# Volatility updated, new implied volatility is: 0.19062
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  748
# Long position is:  16200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -133449.72
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -211.15
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-10
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18615
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15540
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -133715.52
# # of stocks short:  -743.69
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -238.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18051
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  16350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -139302.4
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  48.52
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-12
# Delta updated, new delta is: 0.78
# Volatility updated, new implied volatility is: 0.18336
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  782
# Long position is:  17100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -139778.45
# # of stocks short:  -781.54
# Delta of the option according to BSM:  0.78
# Total error, difference of the portfolios:  343.66
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19399
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15990
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -133047.19
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -143.22
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-16
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19527
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  742
# Long position is:  15750
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -131477.85
# # of stocks short:  -742.18
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -334.77
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18714
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  725
# Long position is:  14250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -127464.38
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -0.4
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-18
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18851
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  702
# Long position is:  13300
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -123129.72
# # of stocks short:  -701.75
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  566.67
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.20536
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -118214.35
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-20
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20513
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  640
# Long position is:  11810
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -110700.59
# # of stocks short:  -639.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -326.79
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20164
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  643
# Long position is:  11560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -111554.45
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -163.0
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-24
# Delta updated, new delta is: 0.65
# Volatility updated, new implied volatility is: 0.1991
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  652
# Long position is:  11680
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -111585.39
# # of stocks short:  -652.16
# Delta of the option according to BSM:  0.65
# Total error, difference of the portfolios:  246.07
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.20578
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  606
# Long position is:  10400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -101162.49
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  241.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-26
# Delta updated, new delta is: 0.52
# Volatility updated, new implied volatility is: 0.2093
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  524
# Long position is:  8090
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -88197.76
# # of stocks short:  -524.3
# Delta of the option according to BSM:  0.52
# Total error, difference of the portfolios:  -307.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Delta updated, new delta is: 0.55
# Volatility updated, new implied volatility is: 0.20258
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  550
# Long position is:  8480
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -93592.28
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -167.68
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-30
# Delta updated, new delta is: 0.59
# Volatility updated, new implied volatility is: 0.20219
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  589
# Long position is:  9450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -100660.01
# # of stocks short:  -589.45
# Delta of the option according to BSM:  0.59
# Total error, difference of the portfolios:  -182.93
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Delta updated, new delta is: 0.6
# Volatility updated, new implied volatility is: 0.19901
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  599
# Long position is:  9550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -104277.86
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  -368.08
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-01
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18787
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  668
# Long position is:  11100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -118659.7
# # of stocks short:  -668.24
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  44.33
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18774
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -129984.11
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -873.04
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-03
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.16251
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  12000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -133408.18
# # of stocks short:  -744.34
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -190.4
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.15924
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  800
# Long position is:  13730
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -145440.71
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -1.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-07
# Delta updated, new delta is: 0.84
# Volatility updated, new implied volatility is: 0.15923
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  844
# Long position is:  15800
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -154359.86
# # of stocks short:  -844.0
# Delta of the option according to BSM:  0.84
# Total error, difference of the portfolios:  -143.08
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.15467
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  867
# Long position is:  16560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -158190.21
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  -43.73
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-09
# Delta updated, new delta is: 0.86
# Volatility updated, new implied volatility is: 0.15524
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  860
# Long position is:  16100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -160369.94
# # of stocks short:  -860.35
# Delta of the option according to BSM:  0.86
# Total error, difference of the portfolios:  117.19
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Delta updated, new delta is: 0.91
# Volatility updated, new implied volatility is: 0.1593
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  906
# Long position is:  19650
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -167481.87
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -19.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-13
# Delta updated, new delta is: 0.88
# Volatility updated, new implied volatility is: 0.16563
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  883
# Long position is:  18180
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -165484.92
# # of stocks short:  -882.87
# Delta of the option according to BSM:  0.88
# Total error, difference of the portfolios:  -140.77
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# =============== REHEDGE =========================
# ...
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -122437.03
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  98.15
# =================================================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -123042.42
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -25.39
# =================================================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -123950.51
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -158.09
# =================================================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121050.26
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  600.25
# =================================================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -119973.23
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -222.97
# =================================================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -120156.25
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -133.03
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -120522.3
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -166.05
# =================================================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -122310.32
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -838.02
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -121360.0
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  780.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -111748.97
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -248.62
# =================================================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -113397.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  1.65
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -114355.66
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  41.66
# =================================================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -113972.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -276.66
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -114873.16
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -90.84
# =================================================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -115454.56
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  168.61
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -114266.22
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  78.34
# =================================================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -114183.16
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -156.94
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -113180.1
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -496.94
# =================================================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -112343.14
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -113.05
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -112100.36
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  542.78
# =================================================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -110452.02
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -141.65
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -110528.68
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -326.67
# =================================================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -110809.8
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -161.11
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -109314.79
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  215.01
# =================================================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -106625.04
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  379.74
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -107474.77
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -459.73
# =================================================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -108797.28
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -352.51
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -109103.95
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -206.67
# =================================================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -111148.41
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -494.46
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -113448.43
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  149.98
# =================================================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -112860.65
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -962.22
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -114509.0
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  81.65
# =================================================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -116163.73
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  415.26
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -116847.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  76.38
# =================================================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -116540.68
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -153.33
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -119089.87
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  1000.81
# =================================================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -118067.64
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -447.77
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -119754.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  503.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  128745.11197806873
# ==================================================

# %%
hedging_frequencies = [1, 2, 5, 10, 30]

results_dict = {'Frequency': [], 'Total_MSE': []}

for freq in hedging_frequencies:
    total_mean_squared_error, total_error, portfolio_values, OPs, REs = delta_hedge(df_result, freq, "C170")
    results_dict['Frequency'].append(freq)
    results_dict['Total_MSE'].append(total_error)

# Plotting
plt.plot(results_dict['Frequency'], results_dict['Total_MSE'], marker='o')
plt.xlabel('Hedging Frequency (days)')
plt.ylabel('Total Mean Squared Error')
plt.title('Total Mean Squared Error vs Hedging Frequency')
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of single call option (for 1000 stocks) according to BSM:  16400.0
# Value of the short position according to BSM:  -123781.57
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of single call option (for 1000 stocks) according to BSM:  17500.0
# Value of the new short position according to BSM:  -124760.05
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  121.52
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-22
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18856
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  720
# Long position is:  17500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-23
# Value of single call option (for 1000 stocks) according to BSM:  20200.0
# Value of the new short position according to BSM:  -130381.38
# # of stocks short:  -719.86
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -100.26
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18519
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  20200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of single call option (for 1000 stocks) according to BSM:  16970.0
# Value of the new short position according to BSM:  -136027.33
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  425.57
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-24
# Delta updated, new delta is: 0.71
# Volatility updated, new implied volatility is: 0.19236
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  706
# Long position is:  16970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-25
# Value of single call option (for 1000 stocks) according to BSM:  18500.0
# Value of the new short position according to BSM:  -126086.99
# # of stocks short:  -705.93
# Delta of the option according to BSM:  0.71
# Total error, difference of the portfolios:  -44.23
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19141
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  18500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of single call option (for 1000 stocks) according to BSM:  19400.0
# Value of the new short position according to BSM:  -132587.64
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -262.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-28
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.18867
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  19400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-29
# Value of single call option (for 1000 stocks) according to BSM:  22030.0
# Value of the new short position according to BSM:  -139560.7
# # of stocks short:  -757.99
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -348.89
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Delta updated, new delta is: 0.81
# Volatility updated, new implied volatility is: 0.17866
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  814
# Long position is:  22030
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of single call option (for 1000 stocks) according to BSM:  24620.0
# Value of the new short position according to BSM:  -152691.1
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  -282.37
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-30
# Delta updated, new delta is: 0.86
# Volatility updated, new implied volatility is: 0.16967
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  860
# Long position is:  24620
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-31
# Value of single call option (for 1000 stocks) according to BSM:  24970.0
# Value of the new short position according to BSM:  -161626.05
# # of stocks short:  -860.31
# Delta of the option according to BSM:  0.86
# Total error, difference of the portfolios:  160.73
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Delta updated, new delta is: 0.85
# Volatility updated, new implied volatility is: 0.1763
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  855
# Long position is:  24970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of single call option (for 1000 stocks) according to BSM:  26000.0
# Value of the new short position according to BSM:  -161911.77
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  -328.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-01
# Delta updated, new delta is: 0.88
# Volatility updated, new implied volatility is: 0.16683
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  881
# Long position is:  26000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-05
# Value of single call option (for 1000 stocks) according to BSM:  26350.0
# Value of the new short position according to BSM:  -167038.24
# # of stocks short:  -880.54
# Delta of the option according to BSM:  0.88
# Total error, difference of the portfolios:  138.67
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.17788
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  871
# Long position is:  26350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -159298.89
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  313.51
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.18197
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  798
# Long position is:  20750
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-07
# Value of single call option (for 1000 stocks) according to BSM:  17000.0
# Value of the new short position according to BSM:  -141776.39
# # of stocks short:  -798.47
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  521.82
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.19135
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  722
# Long position is:  17000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -128697.76
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -347.82
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-08
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18426
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  737
# Long position is:  17100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-11
# Value of single call option (for 1000 stocks) according to BSM:  17600.0
# Value of the new short position according to BSM:  -132161.45
# # of stocks short:  -736.85
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -369.48
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17875
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  759
# Long position is:  17600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -133742.85
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -428.66
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-12
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.16839
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  724
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-13
# Value of single call option (for 1000 stocks) according to BSM:  13570.0
# Value of the new short position according to BSM:  -126148.89
# # of stocks short:  -724.12
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  233.41
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Delta updated, new delta is: 0.69
# Volatility updated, new implied volatility is: 0.1742
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  685
# Long position is:  13570
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of single call option (for 1000 stocks) according to BSM:  14450.0
# Value of the new short position according to BSM:  -120455.18
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  -168.69
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-14
# Delta updated, new delta is: 0.71
# Volatility updated, new implied volatility is: 0.17105
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  713
# Long position is:  14450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-15
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -124724.81
# # of stocks short:  -712.67
# Delta of the option according to BSM:  0.71
# Total error, difference of the portfolios:  170.25
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.176
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  697
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of single call option (for 1000 stocks) according to BSM:  16080.0
# Value of the new short position according to BSM:  -124044.6
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -83.11
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-18
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.17639
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  742
# Long position is:  16080
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-19
# Value of single call option (for 1000 stocks) according to BSM:  16870.0
# Value of the new short position according to BSM:  -132901.43
# # of stocks short:  -742.18
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -26.39
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17687
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  16870
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of single call option (for 1000 stocks) according to BSM:  14520.0
# Value of the new short position according to BSM:  -132978.12
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  362.76
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-20
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18425
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  698
# Long position is:  14520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-21
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -121438.85
# # of stocks short:  -698.21
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  89.2
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18715
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  671
# Long position is:  13520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -117365.34
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  2.54
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-22
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.18852
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -120445.85
# # of stocks short:  -684.04
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -132.41
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18878
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  704
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121089.25
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  601.18
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-26
# Delta updated, new delta is: 0.63
# Volatility updated, new implied volatility is: 0.20085
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  632
# Long position is:  12550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -107721.9
# # of stocks short:  -632.06
# Delta of the option according to BSM:  0.63
# Total error, difference of the portfolios:  -332.95
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.1942
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  608
# Long position is:  11250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -103847.0
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -108.18
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-28
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.19322
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  613
# Long position is:  11300
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -104870.95
# # of stocks short:  -612.53
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -118.51
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Delta updated, new delta is: 0.62
# Volatility updated, new implied volatility is: 0.19178
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  622
# Long position is:  11500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -108017.13
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  -629.07
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-02
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.1792
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  672
# Long position is:  12450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -115904.92
# # of stocks short:  -672.3
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  737.61
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-04
# Delta updated, new delta is: 0.66
# Volatility updated, new implied volatility is: 0.19688
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  660
# Long position is:  13000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -115425.19
# # of stocks short:  -659.91
# Delta of the option according to BSM:  0.66
# Total error, difference of the portfolios:  -274.89
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.19126
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -121349.24
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -113.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-06
# Delta updated, new delta is: 0.73
# Volatility updated, new implied volatility is: 0.18819
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  727
# Long position is:  15200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -130199.15
# # of stocks short:  -727.41
# Delta of the option according to BSM:  0.73
# Total error, difference of the portfolios:  -91.12
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Delta updated, new delta is: 0.75
# Volatility updated, new implied volatility is: 0.19062
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  748
# Long position is:  16200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -133449.72
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -211.15
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-10
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18615
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15540
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -133715.52
# # of stocks short:  -743.69
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -238.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18051
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  16350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -139302.4
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  48.52
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-12
# Delta updated, new delta is: 0.78
# Volatility updated, new implied volatility is: 0.18336
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  782
# Long position is:  17100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -139778.45
# # of stocks short:  -781.54
# Delta of the option according to BSM:  0.78
# Total error, difference of the portfolios:  343.66
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19399
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15990
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -133047.19
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -143.22
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-16
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19527
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  742
# Long position is:  15750
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -131477.85
# # of stocks short:  -742.18
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -334.77
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18714
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  725
# Long position is:  14250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -127464.38
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -0.4
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-18
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18851
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  702
# Long position is:  13300
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -123129.72
# # of stocks short:  -701.75
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  566.67
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.20536
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -118214.35
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-20
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20513
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  640
# Long position is:  11810
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -110700.59
# # of stocks short:  -639.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -326.79
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20164
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  643
# Long position is:  11560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -111554.45
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -163.0
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-24
# Delta updated, new delta is: 0.65
# Volatility updated, new implied volatility is: 0.1991
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  652
# Long position is:  11680
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -111585.39
# # of stocks short:  -652.16
# Delta of the option according to BSM:  0.65
# Total error, difference of the portfolios:  246.07
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.20578
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  606
# Long position is:  10400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -101162.49
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  241.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-26
# Delta updated, new delta is: 0.52
# Volatility updated, new implied volatility is: 0.2093
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  524
# Long position is:  8090
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -88197.76
# # of stocks short:  -524.3
# Delta of the option according to BSM:  0.52
# Total error, difference of the portfolios:  -307.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Delta updated, new delta is: 0.55
# Volatility updated, new implied volatility is: 0.20258
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  550
# Long position is:  8480
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -93592.28
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -167.68
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-30
# Delta updated, new delta is: 0.59
# Volatility updated, new implied volatility is: 0.20219
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  589
# Long position is:  9450
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -100660.01
# # of stocks short:  -589.45
# Delta of the option according to BSM:  0.59
# Total error, difference of the portfolios:  -182.93
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Delta updated, new delta is: 0.6
# Volatility updated, new implied volatility is: 0.19901
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  599
# Long position is:  9550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -104277.86
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  -368.08
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-01
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18787
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  668
# Long position is:  11100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -118659.7
# # of stocks short:  -668.24
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  44.33
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18774
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -129984.11
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -873.04
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-03
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.16251
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  12000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -133408.18
# # of stocks short:  -744.34
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -190.4
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.15924
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  800
# Long position is:  13730
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -145440.71
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -1.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-07
# Delta updated, new delta is: 0.84
# Volatility updated, new implied volatility is: 0.15923
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  844
# Long position is:  15800
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -154359.86
# # of stocks short:  -844.0
# Delta of the option according to BSM:  0.84
# Total error, difference of the portfolios:  -143.08
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.15467
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  867
# Long position is:  16560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -158190.21
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  -43.73
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-09
# Delta updated, new delta is: 0.86
# Volatility updated, new implied volatility is: 0.15524
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  860
# Long position is:  16100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -160369.94
# # of stocks short:  -860.35
# Delta of the option according to BSM:  0.86
# Total error, difference of the portfolios:  117.19
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Delta updated, new delta is: 0.91
# Volatility updated, new implied volatility is: 0.1593
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  906
# Long position is:  19650
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -167481.87
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -19.94
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-13
# Delta updated, new delta is: 0.88
# Volatility updated, new implied volatility is: 0.16563
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  883
# Long position is:  18180
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -165484.92
# # of stocks short:  -882.87
# Delta of the option according to BSM:  0.88
# Total error, difference of the portfolios:  -140.77
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# =============== REHEDGE =========================
# ...
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -122437.03
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  98.15
# =================================================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -123042.42
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -25.39
# =================================================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -123950.51
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -158.09
# =================================================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121050.26
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  600.25
# =================================================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -119973.23
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -222.97
# =================================================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -120156.25
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -133.03
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -120522.3
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -166.05
# =================================================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -122310.32
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -838.02
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -121360.0
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  780.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -111748.97
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -248.62
# =================================================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -113397.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  1.65
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -114355.66
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  41.66
# =================================================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -113972.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -276.66
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -114873.16
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -90.84
# =================================================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -115454.56
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  168.61
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -114266.22
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  78.34
# =================================================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -114183.16
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -156.94
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -113180.1
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -496.94
# =================================================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -112343.14
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -113.05
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -112100.36
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  542.78
# =================================================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -110452.02
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -141.65
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -110528.68
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -326.67
# =================================================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -110809.8
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -161.11
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -109314.79
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  215.01
# =================================================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -106625.04
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  379.74
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -107474.77
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -459.73
# =================================================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -108797.28
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -352.51
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -109103.95
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -206.67
# =================================================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -111148.41
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -494.46
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -113448.43
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  149.98
# =================================================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -112860.65
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -962.22
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -114509.0
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  81.65
# =================================================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -116163.73
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  415.26
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -116847.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  76.38
# =================================================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -116540.68
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -153.33
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -119089.87
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  1000.81
# =================================================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -118067.64
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -447.77
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -119754.32
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  503.32
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  128745.11197806873
# ==================================================

# %%
# NOTE: not ready. The costs dont work as percents yet; they are simply 100 000 * cost
# for illustrative purposes. This corresponds to fixed costs, e.g. 100€ per trade.
# These costs mean fixed costs of 0€, 2000€ and 5000€ per trade.

costs = [0.00, 0.02, 0.05]
plt.figure(figsize=(10, 6))
for c in costs:
    total_mean_squared_error, total_error, portfolio_values, OPs, REs = delta_hedge(df_result, 2, "C170", costs=c) #every other day
    plt.plot(portfolio_values, label=f'Transaction costs: ${c*100}k') # change to % once done

plt.xlabel('Days')
plt.ylabel('Portfolio value')
plt.title('Portfolio value with transactions costs, hedging every other day')
plt.legend()
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of single call option (for 1000 stocks) according to BSM:  16400.0
# Value of the short position according to BSM:  -123781.57
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of single call option (for 1000 stocks) according to BSM:  17500.0
# Value of the new short position according to BSM:  -124760.05
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  121.52
# =================================================
#
#
# =================================================
# Date: 2023-08-23
# Value of single call option (for 1000 stocks) according to BSM:  20200.0
# Value of the new short position according to BSM:  -127498.39
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -38.34
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18519
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  20200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of single call option (for 1000 stocks) according to BSM:  16970.0
# Value of the new short position according to BSM:  -136027.33
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  425.57
# =================================================
#
#
# =================================================
# Date: 2023-08-25
# Value of single call option (for 1000 stocks) according to BSM:  18500.0
# Value of the new short position according to BSM:  -137747.14
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  -189.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19141
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  18500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of single call option (for 1000 stocks) according to BSM:  19400.0
# Value of the new short position according to BSM:  -132587.64
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -262.6
# =================================================
#
#
# =================================================
# Date: 2023-08-29
# Value of single call option (for 1000 stocks) according to BSM:  22030.0
# Value of the new short position according to BSM:  -135479.42
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -261.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Delta updated, new delta is: 0.81
# Volatility updated, new implied volatility is: 0.17866
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  814
# Long position is:  22030
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of single call option (for 1000 stocks) according to BSM:  24620.0
# Value of the new short position according to BSM:  -152691.1
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  -282.37
# =================================================
#
#
# =================================================
# Date: 2023-08-31
# Value of single call option (for 1000 stocks) according to BSM:  24970.0
# Value of the new short position according to BSM:  -152870.11
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  170.99
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Delta updated, new delta is: 0.85
# Volatility updated, new implied volatility is: 0.1763
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  855
# Long position is:  24970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of single call option (for 1000 stocks) according to BSM:  26000.0
# Value of the new short position according to BSM:  -161911.77
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  -328.81
# =================================================
#
#
# =================================================
# Date: 2023-09-05
# Value of single call option (for 1000 stocks) according to BSM:  26350.0
# Value of the new short position according to BSM:  -162116.87
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  144.9
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.17788
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  871
# Long position is:  26350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -159298.89
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  313.51
# =================================================
#
#
# =================================================
# Date: 2023-09-07
# Value of single call option (for 1000 stocks) according to BSM:  17000.0
# Value of the new short position according to BSM:  -154639.5
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  909.39
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.19135
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  722
# Long position is:  17000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -128697.76
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -347.82
# =================================================
#
#
# =================================================
# Date: 2023-09-11
# Value of single call option (for 1000 stocks) according to BSM:  17600.0
# Value of the new short position according to BSM:  -129550.06
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -352.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17875
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  759
# Long position is:  17600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -133742.85
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -428.66
# =================================================
#
#
# =================================================
# Date: 2023-09-13
# Value of single call option (for 1000 stocks) according to BSM:  13570.0
# Value of the new short position according to BSM:  -132157.35
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  305.49
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Delta updated, new delta is: 0.69
# Volatility updated, new implied volatility is: 0.1742
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  685
# Long position is:  13570
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of single call option (for 1000 stocks) according to BSM:  14450.0
# Value of the new short position according to BSM:  -120455.18
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  -168.69
# =================================================
#
#
# =================================================
# Date: 2023-09-15
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -119954.83
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  150.35
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.176
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  697
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of single call option (for 1000 stocks) according to BSM:  16080.0
# Value of the new short position according to BSM:  -124044.6
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -83.11
# =================================================
#
#
# =================================================
# Date: 2023-09-19
# Value of single call option (for 1000 stocks) according to BSM:  16870.0
# Value of the new short position according to BSM:  -124811.3
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  23.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17687
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  16870
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of single call option (for 1000 stocks) according to BSM:  14520.0
# Value of the new short position according to BSM:  -132978.12
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  362.76
# =================================================
#
#
# =================================================
# Date: 2023-09-21
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -131796.02
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  182.1
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18715
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  671
# Long position is:  13520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -117365.34
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  2.54
# =================================================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -118231.53
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  -116.19
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18878
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  704
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121089.25
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  601.18
# =================================================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -120011.87
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -222.62
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.1942
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  608
# Long position is:  11250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -103847.0
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -108.18
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -104163.36
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -116.37
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Delta updated, new delta is: 0.62
# Volatility updated, new implied volatility is: 0.19178
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  622
# Long position is:  11500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -108017.13
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  -629.07
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -107177.86
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  669.27
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -111748.97
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -248.62
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.19126
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -121349.24
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -113.94
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -122374.78
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.54
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Delta updated, new delta is: 0.75
# Volatility updated, new implied volatility is: 0.19062
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  748
# Long position is:  16200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -133449.72
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -211.15
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -134504.51
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -244.79
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18051
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  16350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -139302.4
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  48.52
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -137868.6
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  323.8
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19399
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15990
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -133047.19
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -143.22
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -131878.41
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -331.22
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18714
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  725
# Long position is:  14250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -127464.38
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -0.4
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -127188.92
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  575.46
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.20536
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -118214.35
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.81
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -118296.41
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -332.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20164
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  643
# Long position is:  11560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -111554.45
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -163.0
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -110049.39
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  225.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.20578
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  606
# Long position is:  10400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -101162.49
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  241.94
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -101968.68
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -416.2
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Delta updated, new delta is: 0.55
# Volatility updated, new implied volatility is: 0.20258
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  550
# Long position is:  8480
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -93592.28
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -167.68
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -93856.09
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -163.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Delta updated, new delta is: 0.6
# Volatility updated, new implied volatility is: 0.19901
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  599
# Long position is:  9550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -104277.86
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  -368.08
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -106435.7
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  292.16
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18774
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -129984.11
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -873.04
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -131882.55
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -168.44
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.15924
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  800
# Long position is:  13730
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -145440.71
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -1.78
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -146296.62
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -95.91
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.15467
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  867
# Long position is:  16560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -158190.21
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  -43.73
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -161650.44
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  89.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Delta updated, new delta is: 0.91
# Volatility updated, new implied volatility is: 0.1593
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  906
# Long position is:  19650
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -167481.87
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -19.94
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -169874.47
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -202.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  97927.7658361328
# ==================================================
# ================ Initial values: =================
# Date: 2023-08-21
# Value of single call option (for 1000 stocks) according to BSM:  16400.0
# Value of the short position according to BSM:  -123781.57
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of single call option (for 1000 stocks) according to BSM:  17500.0
# Value of the new short position according to BSM:  -124760.05
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  121.52
# =================================================
#
#
# =================================================
# Date: 2023-08-23
# Value of single call option (for 1000 stocks) according to BSM:  20200.0
# Value of the new short position according to BSM:  -127498.39
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -38.34
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18519
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  20200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of single call option (for 1000 stocks) according to BSM:  16970.0
# Value of the new short position according to BSM:  -136027.33
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  425.57
# =================================================
#
#
# =================================================
# Date: 2023-08-25
# Value of single call option (for 1000 stocks) according to BSM:  18500.0
# Value of the new short position according to BSM:  -137747.14
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  -189.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19141
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  18500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of single call option (for 1000 stocks) according to BSM:  19400.0
# Value of the new short position according to BSM:  -132587.64
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -262.6
# =================================================
#
#
# =================================================
# Date: 2023-08-29
# Value of single call option (for 1000 stocks) according to BSM:  22030.0
# Value of the new short position according to BSM:  -135479.42
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -261.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Delta updated, new delta is: 0.81
# Volatility updated, new implied volatility is: 0.17866
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  814
# Long position is:  22030
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of single call option (for 1000 stocks) according to BSM:  24620.0
# Value of the new short position according to BSM:  -152691.1
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  -282.37
# =================================================
#
#
# =================================================
# Date: 2023-08-31
# Value of single call option (for 1000 stocks) according to BSM:  24970.0
# Value of the new short position according to BSM:  -152870.11
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  170.99
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Delta updated, new delta is: 0.85
# Volatility updated, new implied volatility is: 0.1763
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  855
# Long position is:  24970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of single call option (for 1000 stocks) according to BSM:  26000.0
# Value of the new short position according to BSM:  -161911.77
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  -328.81
# =================================================
#
#
# =================================================
# Date: 2023-09-05
# Value of single call option (for 1000 stocks) according to BSM:  26350.0
# Value of the new short position according to BSM:  -162116.87
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  144.9
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.17788
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  871
# Long position is:  26350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -159298.89
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  313.51
# =================================================
#
#
# =================================================
# Date: 2023-09-07
# Value of single call option (for 1000 stocks) according to BSM:  17000.0
# Value of the new short position according to BSM:  -154639.5
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  909.39
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.19135
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  722
# Long position is:  17000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -128697.76
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -347.82
# =================================================
#
#
# =================================================
# Date: 2023-09-11
# Value of single call option (for 1000 stocks) according to BSM:  17600.0
# Value of the new short position according to BSM:  -129550.06
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -352.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17875
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  759
# Long position is:  17600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -133742.85
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -428.66
# =================================================
#
#
# =================================================
# Date: 2023-09-13
# Value of single call option (for 1000 stocks) according to BSM:  13570.0
# Value of the new short position according to BSM:  -132157.35
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  305.49
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Delta updated, new delta is: 0.69
# Volatility updated, new implied volatility is: 0.1742
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  685
# Long position is:  13570
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of single call option (for 1000 stocks) according to BSM:  14450.0
# Value of the new short position according to BSM:  -120455.18
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  -168.69
# =================================================
#
#
# =================================================
# Date: 2023-09-15
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -119954.83
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  150.35
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.176
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  697
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of single call option (for 1000 stocks) according to BSM:  16080.0
# Value of the new short position according to BSM:  -124044.6
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -83.11
# =================================================
#
#
# =================================================
# Date: 2023-09-19
# Value of single call option (for 1000 stocks) according to BSM:  16870.0
# Value of the new short position according to BSM:  -124811.3
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  23.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17687
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  16870
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of single call option (for 1000 stocks) according to BSM:  14520.0
# Value of the new short position according to BSM:  -132978.12
# # of stocks short:  -757.75
# ...
# Delta updated, new delta is: 0.75
# Volatility updated, new implied volatility is: 0.19062
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  748
# Long position is:  16200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -133449.72
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -211.15
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -134504.51
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -244.79
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18051
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  16350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -139302.4
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  48.52
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -137868.6
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  323.8
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19399
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15990
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -133047.19
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -143.22
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -131878.41
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -331.22
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18714
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  725
# Long position is:  14250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -127464.38
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -0.4
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -127188.92
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  575.46
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.20536
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -118214.35
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.81
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -118296.41
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -332.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20164
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  643
# Long position is:  11560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -111554.45
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -163.0
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -110049.39
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  225.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.20578
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  606
# Long position is:  10400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -101162.49
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  241.94
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -101968.68
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -416.2
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Delta updated, new delta is: 0.55
# Volatility updated, new implied volatility is: 0.20258
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  550
# Long position is:  8480
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -93592.28
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -167.68
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -93856.09
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -163.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Delta updated, new delta is: 0.6
# Volatility updated, new implied volatility is: 0.19901
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  599
# Long position is:  9550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -104277.86
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  -368.08
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -106435.7
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  292.16
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18774
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -129984.11
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -873.04
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -131882.55
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -168.44
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.15924
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  800
# Long position is:  13730
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -145440.71
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -1.78
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -146296.62
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -95.91
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.15467
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  867
# Long position is:  16560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -158190.21
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  -43.73
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -161650.44
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  89.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Delta updated, new delta is: 0.91
# Volatility updated, new implied volatility is: 0.1593
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  906
# Long position is:  19650
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -167481.87
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -19.94
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -169874.47
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -202.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  97927.7658361328
# ==================================================

# %%
plt.figure(figsize=(10, 6))
total_mean_squared_error, total_error, portfolio_values, OPs, REs = delta_hedge(df_result, 2, "C170")
plt.plot(OPs, label=f'OP') # change to % once done
plt.plot(REs, label=f'RE')
plt.plot(portfolio_values, label=f'Portfolio value')

plt.xlabel('Days')
plt.ylabel('Portfolio value')
plt.title('OP, RE and portfolio values')
plt.legend()
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of single call option (for 1000 stocks) according to BSM:  16400.0
# Value of the short position according to BSM:  -123781.57
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of single call option (for 1000 stocks) according to BSM:  17500.0
# Value of the new short position according to BSM:  -124760.05
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  121.52
# =================================================
#
#
# =================================================
# Date: 2023-08-23
# Value of single call option (for 1000 stocks) according to BSM:  20200.0
# Value of the new short position according to BSM:  -127498.39
# # of stocks short:  -703.94
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -38.34
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18519
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  20200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of single call option (for 1000 stocks) according to BSM:  16970.0
# Value of the new short position according to BSM:  -136027.33
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  425.57
# =================================================
#
#
# =================================================
# Date: 2023-08-25
# Value of single call option (for 1000 stocks) according to BSM:  18500.0
# Value of the new short position according to BSM:  -137747.14
# # of stocks short:  -771.22
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  -189.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19141
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  18500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of single call option (for 1000 stocks) according to BSM:  19400.0
# Value of the new short position according to BSM:  -132587.64
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -262.6
# =================================================
#
#
# =================================================
# Date: 2023-08-29
# Value of single call option (for 1000 stocks) according to BSM:  22030.0
# Value of the new short position according to BSM:  -135479.42
# # of stocks short:  -735.82
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -261.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Delta updated, new delta is: 0.81
# Volatility updated, new implied volatility is: 0.17866
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  814
# Long position is:  22030
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of single call option (for 1000 stocks) according to BSM:  24620.0
# Value of the new short position according to BSM:  -152691.1
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  -282.37
# =================================================
#
#
# =================================================
# Date: 2023-08-31
# Value of single call option (for 1000 stocks) according to BSM:  24970.0
# Value of the new short position according to BSM:  -152870.11
# # of stocks short:  -813.7
# Delta of the option according to BSM:  0.81
# Total error, difference of the portfolios:  170.99
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Delta updated, new delta is: 0.85
# Volatility updated, new implied volatility is: 0.1763
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  855
# Long position is:  24970
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of single call option (for 1000 stocks) according to BSM:  26000.0
# Value of the new short position according to BSM:  -161911.77
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  -328.81
# =================================================
#
#
# =================================================
# Date: 2023-09-05
# Value of single call option (for 1000 stocks) according to BSM:  26350.0
# Value of the new short position according to BSM:  -162116.87
# # of stocks short:  -854.6
# Delta of the option according to BSM:  0.85
# Total error, difference of the portfolios:  144.9
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.17788
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  871
# Long position is:  26350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -159298.89
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  313.51
# =================================================
#
#
# =================================================
# Date: 2023-09-07
# Value of single call option (for 1000 stocks) according to BSM:  17000.0
# Value of the new short position according to BSM:  -154639.5
# # of stocks short:  -870.91
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  909.39
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.19135
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  722
# Long position is:  17000
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -128697.76
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -347.82
# =================================================
#
#
# =================================================
# Date: 2023-09-11
# Value of single call option (for 1000 stocks) according to BSM:  17600.0
# Value of the new short position according to BSM:  -129550.06
# # of stocks short:  -722.29
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -352.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17875
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  759
# Long position is:  17600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -133742.85
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  -428.66
# =================================================
#
#
# =================================================
# Date: 2023-09-13
# Value of single call option (for 1000 stocks) according to BSM:  13570.0
# Value of the new short position according to BSM:  -132157.35
# # of stocks short:  -758.61
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  305.49
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Delta updated, new delta is: 0.69
# Volatility updated, new implied volatility is: 0.1742
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  685
# Long position is:  13570
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of single call option (for 1000 stocks) according to BSM:  14450.0
# Value of the new short position according to BSM:  -120455.18
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  -168.69
# =================================================
#
#
# =================================================
# Date: 2023-09-15
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -119954.83
# # of stocks short:  -685.42
# Delta of the option according to BSM:  0.69
# Total error, difference of the portfolios:  150.35
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.176
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  697
# Long position is:  14100
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of single call option (for 1000 stocks) according to BSM:  16080.0
# Value of the new short position according to BSM:  -124044.6
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -83.11
# =================================================
#
#
# =================================================
# Date: 2023-09-19
# Value of single call option (for 1000 stocks) according to BSM:  16870.0
# Value of the new short position according to BSM:  -124811.3
# # of stocks short:  -697.0
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  23.3
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Delta updated, new delta is: 0.76
# Volatility updated, new implied volatility is: 0.17687
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  758
# Long position is:  16870
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of single call option (for 1000 stocks) according to BSM:  14520.0
# Value of the new short position according to BSM:  -132978.12
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  362.76
# =================================================
#
#
# =================================================
# Date: 2023-09-21
# Value of single call option (for 1000 stocks) according to BSM:  13520.0
# Value of the new short position according to BSM:  -131796.02
# # of stocks short:  -757.75
# Delta of the option according to BSM:  0.76
# Total error, difference of the portfolios:  182.1
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Delta updated, new delta is: 0.67
# Volatility updated, new implied volatility is: 0.18715
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  671
# Long position is:  13520
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of single call option (for 1000 stocks) according to BSM:  14100.0
# Value of the new short position according to BSM:  -117365.34
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  2.54
# =================================================
#
#
# =================================================
# Date: 2023-09-25
# Value of single call option (for 1000 stocks) according to BSM:  14850.0
# Value of the new short position according to BSM:  -118231.53
# # of stocks short:  -671.46
# Delta of the option according to BSM:  0.67
# Total error, difference of the portfolios:  -116.19
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Delta updated, new delta is: 0.7
# Volatility updated, new implied volatility is: 0.18878
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  704
# Long position is:  14850
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of single call option (for 1000 stocks) according to BSM:  12550.0
# Value of the new short position according to BSM:  -121089.25
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  601.18
# =================================================
#
#
# =================================================
# Date: 2023-09-27
# Value of single call option (for 1000 stocks) according to BSM:  11250.0
# Value of the new short position according to BSM:  -120011.87
# # of stocks short:  -704.17
# Delta of the option according to BSM:  0.7
# Total error, difference of the portfolios:  -222.62
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.1942
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  608
# Long position is:  11250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of single call option (for 1000 stocks) according to BSM:  11300.0
# Value of the new short position according to BSM:  -103847.0
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -108.18
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of single call option (for 1000 stocks) according to BSM:  11500.0
# Value of the new short position according to BSM:  -104163.36
# # of stocks short:  -608.4
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -116.37
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Delta updated, new delta is: 0.62
# Volatility updated, new implied volatility is: 0.19178
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  622
# Long position is:  11500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of single call option (for 1000 stocks) according to BSM:  12450.0
# Value of the new short position according to BSM:  -108017.13
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  -629.07
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of single call option (for 1000 stocks) according to BSM:  12280.0
# Value of the new short position according to BSM:  -107177.86
# # of stocks short:  -621.68
# Delta of the option according to BSM:  0.62
# Total error, difference of the portfolios:  669.27
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.19768
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  639
# Long position is:  12280
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of single call option (for 1000 stocks) according to BSM:  13000.0
# Value of the new short position according to BSM:  -110950.35
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -85.01
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -111748.97
# # of stocks short:  -638.89
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -248.62
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.19126
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of single call option (for 1000 stocks) according to BSM:  15200.0
# Value of the new short position according to BSM:  -121349.24
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -113.94
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of single call option (for 1000 stocks) according to BSM:  16200.0
# Value of the new short position according to BSM:  -122374.78
# # of stocks short:  -683.7
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.54
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Delta updated, new delta is: 0.75
# Volatility updated, new implied volatility is: 0.19062
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  748
# Long position is:  16200
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of single call option (for 1000 stocks) according to BSM:  15540.0
# Value of the new short position according to BSM:  -133449.72
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -211.15
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of single call option (for 1000 stocks) according to BSM:  16350.0
# Value of the new short position according to BSM:  -134504.51
# # of stocks short:  -748.08
# Delta of the option according to BSM:  0.75
# Total error, difference of the portfolios:  -244.79
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Delta updated, new delta is: 0.77
# Volatility updated, new implied volatility is: 0.18051
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  771
# Long position is:  16350
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of single call option (for 1000 stocks) according to BSM:  17100.0
# Value of the new short position according to BSM:  -139302.4
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  48.52
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of single call option (for 1000 stocks) according to BSM:  15990.0
# Value of the new short position according to BSM:  -137868.6
# # of stocks short:  -770.86
# Delta of the option according to BSM:  0.77
# Total error, difference of the portfolios:  323.8
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.19399
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  744
# Long position is:  15990
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of single call option (for 1000 stocks) according to BSM:  15750.0
# Value of the new short position according to BSM:  -133047.19
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -143.22
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of single call option (for 1000 stocks) according to BSM:  14250.0
# Value of the new short position according to BSM:  -131878.41
# # of stocks short:  -744.44
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -331.22
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Delta updated, new delta is: 0.72
# Volatility updated, new implied volatility is: 0.18714
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  725
# Long position is:  14250
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of single call option (for 1000 stocks) according to BSM:  13300.0
# Value of the new short position according to BSM:  -127464.38
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  -0.4
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of single call option (for 1000 stocks) according to BSM:  13600.0
# Value of the new short position according to BSM:  -127188.92
# # of stocks short:  -724.89
# Delta of the option according to BSM:  0.72
# Total error, difference of the portfolios:  575.46
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Delta updated, new delta is: 0.68
# Volatility updated, new implied volatility is: 0.20536
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  684
# Long position is:  13600
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of single call option (for 1000 stocks) according to BSM:  11810.0
# Value of the new short position according to BSM:  -118214.35
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -25.81
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of single call option (for 1000 stocks) according to BSM:  11560.0
# Value of the new short position according to BSM:  -118296.41
# # of stocks short:  -683.79
# Delta of the option according to BSM:  0.68
# Total error, difference of the portfolios:  -332.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Delta updated, new delta is: 0.64
# Volatility updated, new implied volatility is: 0.20164
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  643
# Long position is:  11560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of single call option (for 1000 stocks) according to BSM:  11680.0
# Value of the new short position according to BSM:  -111554.45
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  -163.0
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of single call option (for 1000 stocks) according to BSM:  10400.0
# Value of the new short position according to BSM:  -110049.39
# # of stocks short:  -643.19
# Delta of the option according to BSM:  0.64
# Total error, difference of the portfolios:  225.06
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Delta updated, new delta is: 0.61
# Volatility updated, new implied volatility is: 0.20578
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  606
# Long position is:  10400
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of single call option (for 1000 stocks) according to BSM:  8090.0
# Value of the new short position according to BSM:  -101162.49
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  241.94
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of single call option (for 1000 stocks) according to BSM:  8480.0
# Value of the new short position according to BSM:  -101968.68
# # of stocks short:  -606.16
# Delta of the option according to BSM:  0.61
# Total error, difference of the portfolios:  -416.2
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Delta updated, new delta is: 0.55
# Volatility updated, new implied volatility is: 0.20258
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  550
# Long position is:  8480
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of single call option (for 1000 stocks) according to BSM:  9450.0
# Value of the new short position according to BSM:  -93592.28
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -167.68
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of single call option (for 1000 stocks) according to BSM:  9550.0
# Value of the new short position according to BSM:  -93856.09
# # of stocks short:  -549.61
# Delta of the option according to BSM:  0.55
# Total error, difference of the portfolios:  -163.81
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Delta updated, new delta is: 0.6
# Volatility updated, new implied volatility is: 0.19901
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  599
# Long position is:  9550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of single call option (for 1000 stocks) according to BSM:  11100.0
# Value of the new short position according to BSM:  -104277.86
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  -368.08
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of single call option (for 1000 stocks) according to BSM:  13550.0
# Value of the new short position according to BSM:  -106435.7
# # of stocks short:  -599.4
# Delta of the option according to BSM:  0.6
# Total error, difference of the portfolios:  292.16
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Delta updated, new delta is: 0.74
# Volatility updated, new implied volatility is: 0.18774
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  736
# Long position is:  13550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of single call option (for 1000 stocks) according to BSM:  12000.0
# Value of the new short position according to BSM:  -129984.11
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -873.04
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of single call option (for 1000 stocks) according to BSM:  13730.0
# Value of the new short position according to BSM:  -131882.55
# # of stocks short:  -735.83
# Delta of the option according to BSM:  0.74
# Total error, difference of the portfolios:  -168.44
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Delta updated, new delta is: 0.8
# Volatility updated, new implied volatility is: 0.15924
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  800
# Long position is:  13730
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of single call option (for 1000 stocks) according to BSM:  15800.0
# Value of the new short position according to BSM:  -145440.71
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -1.78
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of single call option (for 1000 stocks) according to BSM:  16560.0
# Value of the new short position according to BSM:  -146296.62
# # of stocks short:  -799.92
# Delta of the option according to BSM:  0.8
# Total error, difference of the portfolios:  -95.91
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Delta updated, new delta is: 0.87
# Volatility updated, new implied volatility is: 0.15467
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  867
# Long position is:  16560
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of single call option (for 1000 stocks) according to BSM:  16100.0
# Value of the new short position according to BSM:  -158190.21
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  -43.73
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of single call option (for 1000 stocks) according to BSM:  19650.0
# Value of the new short position according to BSM:  -161650.44
# # of stocks short:  -867.22
# Delta of the option according to BSM:  0.87
# Total error, difference of the portfolios:  89.78
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Delta updated, new delta is: 0.91
# Volatility updated, new implied volatility is: 0.1593
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  906
# Long position is:  19650
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of single call option (for 1000 stocks) according to BSM:  18180.0
# Value of the new short position according to BSM:  -167481.87
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -19.94
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of single call option (for 1000 stocks) according to BSM:  20370.0
# Value of the new short position according to BSM:  -169874.47
# # of stocks short:  -906.29
# Delta of the option according to BSM:  0.91
# Total error, difference of the portfolios:  -202.6
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Delta updated, new delta is: 0.92
# Volatility updated, new implied volatility is: 0.15721
# To delta-hedge a single long call option, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to hold short to balance the portfolio:  924
# Long position is:  20370
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of single call option (for 1000 stocks) according to BSM:  20750.0
# Value of the new short position according to BSM:  -173668.07
# # of stocks short:  -923.72
# Delta of the option according to BSM:  0.92
# Total error, difference of the portfolios:  -146.52
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  97927.7658361328
# ==================================================

# %% [markdown]
# # Delta hedging a Straddle option strategy

# %% [markdown]
# A Straddle is a combination option trading strategy. Straddle consists of 1 call option and 1 put option, with the same strike price and maturity of the same underlying stock. The idea of making profit using Straddle is that the investor expects the underlying to go to a sharp direction, either up or down.

# %%
# TODO: Copy-paste spaghetti, refactor when time
# - Give stuff as parameter instead of declaring the in the function
# - Printing to its own function/module
def delta_hedge_straddle(option_prices, freq):
    # Apple stock is sold in 1000 pcs units
    # Lets assume that the amount is same for put and call options
    # Not sure if they can be different, like 800 puts and 1000 calls
    option_amount = 1000

    # 3-Month Treasury Yield taken on a daily basis regarding our hedging interval
    interest_rate = option_prices.iloc[0]['Interest rate'] 
    stock_price = option_prices.iloc[0]['Underlying']

    # Adjust here the call and put prices for your liking
    # STRADDLE = Same option with same strikes and maturity, put both call and put options
    call_option_price = option_prices.iloc[0]['C180']
    put_option_price = option_prices.iloc[0]['P180']
    strike = 180
    
    time_to_maturity = option_prices.iloc[0]['T']
    call_volatility = implied_volatility(price=call_option_price, S=stock_price, K=strike, t=time_to_maturity, r=interest_rate, flag='c')
    put_volatility = implied_volatility(price=put_option_price, S=stock_price, K=strike, t=time_to_maturity, r=interest_rate, flag='p')
    
    # Initial stuff at t = 0
    call_bsm = BSM(kind='call', S0=stock_price, K=strike, T=time_to_maturity, r=interest_rate, sigma=call_volatility)
    put_bsm = BSM(kind='put', S0=stock_price, K=strike, T=time_to_maturity, r=interest_rate, sigma=put_volatility)

    # Forming the straddle portfolio
    put_delta = put_bsm.delta()
    call_delta = call_bsm.delta()

    # Long position consists of both of the option values
    OP = call_bsm.value() * option_amount + put_bsm.value() * option_amount

    # Short position, the replicating portfolio, consists of the call and put delta amounts of the underlying 
    RE = - (call_delta * stock_price * option_amount + put_delta * stock_price * option_amount)

    # Combined delta of the options
    combined_delta = call_delta + put_delta

    print("================ Initial values: =================")
    print("Date:", option_prices.iloc[0]['Date'])
    print("Value of long Straddle portfolio: ", round(OP, 4))
    print('Call delta: ', round(call_delta, 4))
    print('Put delta: ', round(put_delta, 4))
    print("Delta of the Straddle (call delta + put delta): ", round(combined_delta, 4))
    print("Value of the short Straddle portfolio: ", round(RE, 4))
    print('==================================================')
    print('\n')

    # Keep track of the mean squared error values, which means changes in the portfolios
    total_mean_squared_error = []
    
    # Next we calculate changes in OP and RE and let A_0 = d OP + d RE
    # Hedge as long as there are dates in the dataframe
    for i in range(1, len(option_prices)-1):
        new_call_bsm_obj = BSM(kind='call', S0=option_prices['Underlying'][i], K=strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=call_volatility)
        new_put_bsm_obj = BSM(kind='put', S0=option_prices['Underlying'][i], K=strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=put_volatility)
        new_OP = new_call_bsm_obj.value() * option_amount + new_put_bsm_obj.value() * option_amount
        new_RE = -combined_delta * option_prices['Underlying'][i] * option_amount
        d_OP = new_OP - OP
        d_RE = new_RE - RE
        #d_RE = combined_delta * (option_prices['Underlying'][i+1] - option_prices['Underlying'][i]) * option_amount
        a_0 = d_OP + d_RE
        total_mean_squared_error.append(a_0**2)

        print('=================================================')
        print("Date:", option_prices['Date'][i])
        print("Value of Straddle position: ", round(new_OP, 2))
        print("Value of the delta of the Straddle position: ", round(combined_delta, 2))
        print("Value of the new short position according to BSM: ", round(new_RE, 2))
        print("Difference of the long positions: ", round(OP - new_OP))
        print("Difference of the short positions: ", round(RE - new_RE))
        print("A_0, total error, difference of the portfolios: ", a_0)
        print('=================================================')
        print('\n')

        OP = new_OP
        RE = new_RE

        # Change the modulo for different intervals, 1 = every day, 30 = every month and so on
        # Delta and volatility will be updated when we rehedge
        # As time goes by, the stock price moves/changes. This will affect the delta of the stock option, delta of the underlying is always 1
        # In a real world scenario this hedging costs money, and will be simulated if we have time also in this
        if i % freq == 0:
            put_delta = new_put_bsm_obj.delta()
            call_delta= new_call_bsm_obj.delta()
            combined_delta =  put_delta + call_delta
            call_volatility = BSM(kind='call', S0=option_prices['Underlying'][i], K=strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=call_volatility).implied_vol(option_prices['C180'][i])
            put_volatility = BSM(kind='put', S0=option_prices['Underlying'][i], K=strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=put_volatility).implied_vol(option_prices['P180'][i])

            print('=============== REHEDGE =========================')
            print("Rehedging date:", option_prices['Date'][i])
            print("Combined Delta updated, new combined Delta is:", round(combined_delta, 4))
            print("Call Delta updated, new Call Delta is:", round(call_delta, 4))
            print("Put Delta updated, new Put Delta is:", round(put_delta, 4))
            print("Volatilities updated, new implied volatility for call option is:", round(call_volatility, 5))
            print("Volatilities updated, new implied volatility for put option is:", round(put_volatility, 5))
            print('To delta-hedge the Straddle position, we need to readjust the RE:')
            
            # We have to solve a linear equation, where the delta of the portfolio is zero
            # And we have to readjust by shorting delta amount of the underlying
            # Delta of the underlying is always 1
            RE = -combined_delta * option_prices['Underlying'][i] * option_amount
            
            # Option_amount is the amount of options
            amount = -(combined_delta * option_amount)
            if amount > 0:
                print('Readjusting replicating portoflio RE, amount options to buy to balance the portfolio: ', round(amount, 4))
            elif amount < 0:
                print('Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio: ', round(-amount, 4))
            else:
                print('Portfolio is in balance, no need for readjustment')
            print('Long position is: ', round(OP))
            print('=============== REHEDGE ENDS ====================')
            print('\n')
        
    total_error = sum(total_mean_squared_error) - total_mean_squared_error[-1] # Sum 1 to n-1 of the MSEs
    total_error *= (1 / (len(total_mean_squared_error)-1) )
    print('========== Total Mean Squared Error ==============')
    print("The total mean squared error is : ", total_error)
    print('==================================================')

    return total_mean_squared_error, total_error # return daily errors and the total error for plotting purposes

# %%
hedging_frequencies = [1, 10, 30]
plt.figure(figsize=(10, 6))
for freq in hedging_frequencies:
    total_mean_squared_error, _ = delta_hedge_straddle(df_result, freq)
    plt.plot(total_mean_squared_error, label=f'Hedging Frequency: {freq} days')

plt.xlabel('Days')
plt.ylabel('Daily Error')
plt.title('Daily Error vs Hedging Frequency')
plt.legend()
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of long Straddle portfolio:  21150.0
# Call delta:  0.5543
# Put delta:  -0.4446
# Delta of the Straddle (call delta + put delta):  0.1098
# Value of the short Straddle portfolio:  -19302.5368
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of Straddle position:  21260.57
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19455.12
# Difference of the long positions:  -111
# Difference of the short positions:  153
# A_0, total error, difference of the portfolios:  -42.01946813223549
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-22
# Combined Delta updated, new combined Delta is: 0.1501
# Call Delta updated, new Call Delta is: 0.5766
# Put Delta updated, new Put Delta is: -0.4265
# Volatilities updated, new implied volatility for call option is: 0.17638
# Volatilities updated, new implied volatility for put option is: 0.21344
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  150.1423
# Long position is:  21261
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-23
# Value of Straddle position:  21930.05
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -27193.78
# Difference of the long positions:  -669
# Difference of the short positions:  584
# A_0, total error, difference of the portfolios:  85.42868428560178
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Combined Delta updated, new combined Delta is: 0.2616
# Call Delta updated, new Call Delta is: 0.6374
# Put Delta updated, new Put Delta is: -0.3758
# Volatilities updated, new implied volatility for call option is: 0.17714
# Volatilities updated, new implied volatility for put option is: 0.21306
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  261.6367
# Long position is:  21930
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of Straddle position:  20963.63
# Value of the delta of the Straddle position:  0.26
# Value of the new short position according to BSM:  -46147.49
# Difference of the long positions:  966
# Difference of the short positions:  -1240
# A_0, total error, difference of the portfolios:  273.73947244342344
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-24
# Combined Delta updated, new combined Delta is: 0.1227
# Call Delta updated, new Call Delta is: 0.5615
# Put Delta updated, new Put Delta is: -0.4388
# Volatilities updated, new implied volatility for call option is: 0.18164
# Volatilities updated, new implied volatility for put option is: 0.21956
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  122.7186
# Long position is:  20964
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-25
# Value of Straddle position:  21823.3
# Value of the delta of the Straddle position:  0.12
# Value of the new short position according to BSM:  -21918.76
# Difference of the long positions:  -860
# Difference of the short positions:  274
# A_0, total error, difference of the portfolios:  586.004206039488
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Combined Delta updated, new combined Delta is: 0.1872
# Call Delta updated, new Call Delta is: 0.5967
# Put Delta updated, new Put Delta is: -0.4095
# Volatilities updated, new implied volatility for call option is: 0.17776
# Volatilities updated, new implied volatility for put option is: 0.2145
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  187.2166
# Long position is:  21823
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of Straddle position:  21459.51
# Value of the delta of the Straddle position:  0.19
# Value of the new short position according to BSM:  -33734.56
# Difference of the long positions:  364
# Difference of the short positions:  296
# A_0, total error, difference of the portfolios:  -659.5868106721755
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-28
# Combined Delta updated, new combined Delta is: 0.2321
# Call Delta updated, new Call Delta is: 0.6213
# Put Delta updated, new Put Delta is: -0.3892
# Volatilities updated, new implied volatility for call option is: 0.17576
# Volatilities updated, new implied volatility for put option is: 0.21055
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  232.1122
# Long position is:  21460
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-29
# Value of Straddle position:  22210.11
# Value of the delta of the Straddle position:  0.23
# Value of the new short position according to BSM:  -42736.5
# Difference of the long positions:  -751
# Difference of the short positions:  912
# A_0, total error, difference of the portfolios:  -161.60428949522247
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Combined Delta updated, new combined Delta is: 0.3439
# Call Delta updated, new Call Delta is: 0.6817
# Put Delta updated, new Put Delta is: -0.3378
# Volatilities updated, new implied volatility for call option is: 0.17367
# Volatilities updated, new implied volatility for put option is: 0.21022
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  343.8608
# Long position is:  22210
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of Straddle position:  23394.74
# Value of the delta of the Straddle position:  0.34
# Value of the new short position according to BSM:  -64525.48
# Difference of the long positions:  -1185
# Difference of the short positions:  1214
# A_0, total error, difference of the portfolios:  -29.196948776574573
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-30
# Combined Delta updated, new combined Delta is: 0.4376
# Call Delta updated, new Call Delta is: 0.7328
# Put Delta updated, new Put Delta is: -0.2952
# Volatilities updated, new implied volatility for call option is: 0.16913
# Volatilities updated, new implied volatility for put option is: 0.20868
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  437.6277
# Long position is:  23395
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-31
# Value of Straddle position:  23131.87
# Value of the delta of the Straddle position:  0.44
# Value of the new short position according to BSM:  -82217.11
# Difference of the long positions:  263
# Difference of the short positions:  96
# A_0, total error, difference of the portfolios:  -359.15026238892096
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Combined Delta updated, new combined Delta is: 0.4485
# Call Delta updated, new Call Delta is: 0.7402
# Put Delta updated, new Put Delta is: -0.2916
# Volatilities updated, new implied volatility for call option is: 0.17157
# Volatilities updated, new implied volatility for put option is: 0.20778
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  448.5445
# Long position is:  23132
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of Straddle position:  23857.67
# Value of the delta of the Straddle position:  0.45
# Value of the new short position according to BSM:  -84981.23
# Difference of the long positions:  -726
# Difference of the short positions:  713
# A_0, total error, difference of the portfolios:  12.620266738780629
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-01
# Combined Delta updated, new combined Delta is: 0.4857
# Call Delta updated, new Call Delta is: 0.7586
# Put Delta updated, new Put Delta is: -0.2729
# Volatilities updated, new implied volatility for call option is: 0.1665
# Volatilities updated, new implied volatility for put option is: 0.20595
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  485.653
# Long position is:  23858
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-05
# Value of Straddle position:  23373.26
# Value of the delta of the Straddle position:  0.49
# Value of the new short position according to BSM:  -92128.37
# Difference of the long positions:  484
# Difference of the short positions:  117
# A_0, total error, difference of the portfolios:  -600.9695775567525
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Combined Delta updated, new combined Delta is: 0.4997
# Call Delta updated, new Call Delta is: 0.7679
# Put Delta updated, new Put Delta is: -0.2683
# Volatilities updated, new implied volatility for call option is: 0.17039
# Volatilities updated, new implied volatility for put option is: 0.20944
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  499.6584
# Long position is:  23373
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of Straddle position:  20873.88
# Value of the delta of the Straddle position:  0.5
# Value of the new short position according to BSM:  -91392.52
# Difference of the long positions:  2499
# Difference of the short positions:  -3393
# A_0, total error, difference of the portfolios:  893.2961953827034
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-06
# Combined Delta updated, new combined Delta is: 0.3101
# Call Delta updated, new Call Delta is: 0.6649
# Put Delta updated, new Put Delta is: -0.3548
# Volatilities updated, new implied volatility for call option is: 0.17801
# Volatilities updated, new implied volatility for put option is: 0.21452
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  310.1311
# Long position is:  20874
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-07
# Value of Straddle position:  20220.09
# Value of the delta of the Straddle position:  0.31
# Value of the new short position according to BSM:  -55066.87
# Difference of the long positions:  654
# Difference of the short positions:  -1659
# A_0, total error, difference of the portfolios:  1005.4159066770044
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Combined Delta updated, new combined Delta is: 0.1428
# Call Delta updated, new Call Delta is: 0.5728
# Put Delta updated, new Put Delta is: -0.4299
# Volatilities updated, new implied volatility for call option is: 0.18514
# Volatilities updated, new implied volatility for put option is: 0.21781
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  142.844
# Long position is:  20220
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of Straddle position:  20766.05
# Value of the delta of the Straddle position:  0.14
# Value of the new short position according to BSM:  -25451.94
# Difference of the long positions:  -546
# Difference of the short positions:  89
# A_0, total error, difference of the portfolios:  457.3921531588021
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-08
# Combined Delta updated, new combined Delta is: 0.16
# Call Delta updated, new Call Delta is: 0.5817
# Put Delta updated, new Put Delta is: -0.4218
# Volatilities updated, new implied volatility for call option is: 0.17609
# Volatilities updated, new implied volatility for put option is: 0.21271
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  159.9538
# Long position is:  20766
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-11
# Value of Straddle position:  20031.29
# Value of the delta of the Straddle position:  0.16
# Value of the new short position according to BSM:  -28689.32
# Difference of the long positions:  735
# Difference of the short positions:  189
# A_0, total error, difference of the portfolios:  -923.5013289196759
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Combined Delta updated, new combined Delta is: 0.1961
# Call Delta updated, new Call Delta is: 0.602
# Put Delta updated, new Put Delta is: -0.4059
# Volatilities updated, new implied volatility for call option is: 0.17424
# Volatilities updated, new implied volatility for put option is: 0.20991
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  196.1313
# Long position is:  20031
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of Straddle position:  19272.84
# Value of the delta of the Straddle position:  0.2
# Value of the new short position according to BSM:  -34577.95
# Difference of the long positions:  758
# Difference of the short positions:  -600
# A_0, total error, difference of the portfolios:  -158.2889137948987
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-12
# Combined Delta updated, new combined Delta is: 0.0972
# Call Delta updated, new Call Delta is: 0.5481
# Put Delta updated, new Put Delta is: -0.4508
# Volatilities updated, new implied volatility for call option is: 0.16933
# Volatilities updated, new implied volatility for put option is: 0.20696
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  97.233
# Long position is:  19273
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-13
# Value of Straddle position:  18682.5
# Value of the delta of the Straddle position:  0.1
# Value of the new short position according to BSM:  -16938.96
# Difference of the long positions:  590
# Difference of the short positions:  -203
# A_0, total error, difference of the portfolios:  -387.1183049528263
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Combined Delta updated, new combined Delta is: 0.024
# Call Delta updated, new Call Delta is: 0.5078
# Put Delta updated, new Put Delta is: -0.4839
# Volatilities updated, new implied volatility for call option is: 0.16608
# Volatilities updated, new implied volatility for put option is: 0.20491
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  23.9702
# Long position is:  18683
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of Straddle position:  18424.56
# Value of the delta of the Straddle position:  0.02
# Value of the new short position according to BSM:  -4212.53
# Difference of the long positions:  258
# Difference of the short positions:  37
# A_0, total error, difference of the portfolios:  -294.6161599510242
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-14
# Combined Delta updated, new combined Delta is: 0.0746
# Call Delta updated, new Call Delta is: 0.5357
# Put Delta updated, new Put Delta is: -0.4611
# Volatilities updated, new implied volatility for call option is: 0.16432
# Volatilities updated, new implied volatility for put option is: 0.20274
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  74.5759
# Long position is:  18425
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-15
# Value of Straddle position:  18115.16
# Value of the delta of the Straddle position:  0.07
# Value of the new short position according to BSM:  -13051.53
# Difference of the long positions:  309
# Difference of the short positions:  -54
# A_0, total error, difference of the portfolios:  -254.96495811654313
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Combined Delta updated, new combined Delta is: 0.0473
# Call Delta updated, new Call Delta is: 0.5207
# Put Delta updated, new Put Delta is: -0.4734
# Volatilities updated, new implied volatility for call option is: 0.16719
# Volatilities updated, new implied volatility for put option is: 0.2093
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  47.307
# Long position is:  18115
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of Straddle position:  18646.69
# Value of the delta of the Straddle position:  0.05
# Value of the new short position according to BSM:  -8419.23
# Difference of the long positions:  -532
# Difference of the short positions:  140
# A_0, total error, difference of the portfolios:  391.5031530446322
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-18
# Combined Delta updated, new combined Delta is: 0.146
# Call Delta updated, new Call Delta is: 0.5753
# Put Delta updated, new Put Delta is: -0.4293
# Volatilities updated, new implied volatility for call option is: 0.16509
# Volatilities updated, new implied volatility for put option is: 0.20184
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  145.9885
# Long position is:  18647
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-19
# Value of Straddle position:  18286.65
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -26142.16
# Difference of the long positions:  360
# Difference of the short positions:  161
# A_0, total error, difference of the portfolios:  -520.6305687819913
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Combined Delta updated, new combined Delta is: 0.1838
# Call Delta updated, new Call Delta is: 0.596
# Put Delta updated, new Put Delta is: -0.4122
# Volatilities updated, new implied volatility for call option is: 0.16838
# Volatilities updated, new implied volatility for put option is: 0.20358
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  183.7539
# Long position is:  18287
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of Straddle position:  18023.74
# Value of the delta of the Straddle position:  0.18
# Value of the new short position according to BSM:  -32246.97
# Difference of the long positions:  263
# Difference of the short positions:  -658
# A_0, total error, difference of the portfolios:  394.93297500141125
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-20
# Combined Delta updated, new combined Delta is: 0.0575
# Call Delta updated, new Call Delta is: 0.5266
# Put Delta updated, new Put Delta is: -0.4691
# Volatilities updated, new implied volatility for call option is: 0.1732
# Volatilities updated, new implied volatility for put option is: 0.21005
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  57.5214
# Long position is:  18024
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-21
# Value of Straddle position:  18447.81
# Value of the delta of the Straddle position:  0.06
# Value of the new short position according to BSM:  -10004.7
# Difference of the long positions:  -424
# Difference of the short positions:  -90
# A_0, total error, difference of the portfolios:  513.80610323984
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Combined Delta updated, new combined Delta is: 0.0031
# Call Delta updated, new Call Delta is: 0.4966
# Put Delta updated, new Put Delta is: -0.4935
# Volatilities updated, new implied volatility for call option is: 0.17677
# Volatilities updated, new implied volatility for put option is: 0.21697
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  3.0519
# Long position is:  18448
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of Straddle position:  18891.96
# Value of the delta of the Straddle position:  0.0
# Value of the new short position according to BSM:  -533.44
# Difference of the long positions:  -444
# Difference of the short positions:  3
# A_0, total error, difference of the portfolios:  441.52115055258344
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-22
# Combined Delta updated, new combined Delta is: 0.0331
# Call Delta updated, new Call Delta is: 0.5128
# Put Delta updated, new Put Delta is: -0.4796
# Volatilities updated, new implied volatility for call option is: 0.18037
# Volatilities updated, new implied volatility for put option is: 0.21709
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  33.1381
# Long position is:  18892
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-25
# Value of Straddle position:  18902.3
# Value of the delta of the Straddle position:  0.03
# Value of the new short position according to BSM:  -5834.95
# Difference of the long positions:  -10
# Difference of the short positions:  43
# A_0, total error, difference of the portfolios:  -32.40232486757486
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Combined Delta updated, new combined Delta is: 0.0737
# Call Delta updated, new Call Delta is: 0.5353
# Put Delta updated, new Put Delta is: -0.4616
# Volatilities updated, new implied volatility for call option is: 0.17924
# Volatilities updated, new implied volatility for put option is: 0.2186
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  73.6501
# Long position is:  18902
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of Straddle position:  18834.37
# Value of the delta of the Straddle position:  0.07
# Value of the new short position according to BSM:  -12664.87
# Difference of the long positions:  68
# Difference of the short positions:  -303
# A_0, total error, difference of the portfolios:  235.50760422352505
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-26
# Combined Delta updated, new combined Delta is: -0.0698
# Call Delta updated, new Call Delta is: 0.4564
# Put Delta updated, new Put Delta is: -0.5262
# Volatilities updated, new implied volatility for call option is: 0.18641
# Volatilities updated, new implied volatility for put option is: 0.22476
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  69.7862
# Long position is:  18834
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-27
# Value of Straddle position:  19514.25
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11893.67
# Difference of the long positions:  -680
# Difference of the short positions:  107
# A_0, total error, difference of the portfolios:  573.1077573500042
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Combined Delta updated, new combined Delta is: -0.1175
# Call Delta updated, new Call Delta is: 0.4307
# Put Delta updated, new Put Delta is: -0.5482
# Volatilities updated, new implied volatility for call option is: 0.18271
# Volatilities updated, new implied volatility for put option is: 0.23031
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  117.5451
# Long position is:  19514
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of Straddle position:  19500.08
# Value of the delta of the Straddle position:  -0.12
# Value of the new short position according to BSM:  20063.77
# Difference of the long positions:  14
# Difference of the short positions:  -31
# A_0, total error, difference of the portfolios:  16.38455723815059
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-28
# Combined Delta updated, new combined Delta is: -0.1113
# Call Delta updated, new Call Delta is: 0.4317
# Put Delta updated, new Put Delta is: -0.543
# Volatilities updated, new implied volatility for call option is: 0.18038
# Volatilities updated, new implied volatility for put option is: 0.2238
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  111.2635
# Long position is:  19500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-29
# Value of Straddle position:  18970.95
# Value of the delta of the Straddle position:  -0.11
# Value of the new short position according to BSM:  19049.43
# Difference of the long positions:  529
# Difference of the short positions:  -58
# A_0, total error, difference of the portfolios:  -471.2725775454892
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Combined Delta updated, new combined Delta is: -0.1
# Call Delta updated, new Call Delta is: 0.4389
# Put Delta updated, new Put Delta is: -0.5389
# Volatilities updated, new implied volatility for call option is: 0.17915
# Volatilities updated, new implied volatility for put option is: 0.22941
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  99.9923
# Long position is:  18971
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of Straddle position:  18787.88
# Value of the delta of the Straddle position:  -0.1
# Value of the new short position according to BSM:  17373.67
# Difference of the long positions:  183
# Difference of the short positions:  -254
# A_0, total error, difference of the portfolios:  70.91102111414511
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-02
# Combined Delta updated, new combined Delta is: -0.0158
# Call Delta updated, new Call Delta is: 0.4845
# Put Delta updated, new Put Delta is: -0.5003
# Volatilities updated, new implied volatility for call option is: 0.1793
# Volatilities updated, new implied volatility for put option is: 0.22185
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  15.783
# Long position is:  18788
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-03
# Value of Straddle position:  18429.51
# Value of the delta of the Straddle position:  -0.02
# Value of the new short position according to BSM:  2720.99
# Difference of the long positions:  358
# Difference of the short positions:  21
# A_0, total error, difference of the portfolios:  -379.67177010838805
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Combined Delta updated, new combined Delta is: -0.0675
# Call Delta updated, new Call Delta is: 0.4571
# Put Delta updated, new Put Delta is: -0.5246
# Volatilities updated, new implied volatility for call option is: 0.18955
# Volatilities updated, new implied volatility for put option is: 0.23255
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  67.5132
# Long position is:  18430
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of Straddle position:  19239.74
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11724.33
# Difference of the long positions:  -810
# Difference of the short positions:  -85
# A_0, total error, difference of the portfolios:  895.294695671957
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-04
# Combined Delta updated, new combined Delta is: -0.0184
# Call Delta updated, new Call Delta is: 0.4843
# Put Delta updated, new Put Delta is: -0.5027
# Volatilities updated, new implied volatility for call option is: 0.18718
# Volatilities updated, new implied volatility for put option is: 0.22297
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  18.4387
# Long position is:  19240
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-05
# Value of Straddle position:  18615.58
# Value of the delta of the Straddle position:  -0.02
# Value of the new short position according to BSM:  3225.11
# Difference of the long positions:  624
# Difference of the short positions:  -23
# A_0, total error, difference of the portfolios:  -601.1157417058662
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Combined Delta updated, new combined Delta is: 0.0195
# Call Delta updated, new Call Delta is: 0.506
# Put Delta updated, new Put Delta is: -0.4865
# Volatilities updated, new implied volatility for call option is: 0.18295
# Volatilities updated, new implied volatility for put option is: 0.22067
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  19.5057
# Long position is:  18616
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of Straddle position:  18395.91
# Value of the delta of the Straddle position:  0.02
# Value of the new short position according to BSM:  -3462.07
# Difference of the long positions:  220
# Difference of the short positions:  50
# A_0, total error, difference of the portfolios:  -269.9893204362511
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-06
# Combined Delta updated, new combined Delta is: 0.107
# Call Delta updated, new Call Delta is: 0.5537
# Put Delta updated, new Put Delta is: -0.4467
# Volatilities updated, new implied volatility for call option is: 0.17776
# Volatilities updated, new implied volatility for put option is: 0.21601
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  106.9938
# Long position is:  18396
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-09
# Value of Straddle position:  17885.86
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19150.82
# Difference of the long positions:  510
# Difference of the short positions:  160
# A_0, total error, difference of the portfolios:  -670.5429926115758
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Combined Delta updated, new combined Delta is: 0.1554
# Call Delta updated, new Call Delta is: 0.5804
# Put Delta updated, new Put Delta is: -0.425
# Volatilities updated, new implied volatility for call option is: 0.18158
# Volatilities updated, new implied volatility for put option is: 0.21655
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  155.4228
# Long position is:  17886
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of Straddle position:  17905.35
# Value of the delta of the Straddle position:  0.16
# Value of the new short position according to BSM:  -27725.87
# Difference of the long positions:  -19
# Difference of the short positions:  -93
# A_0, total error, difference of the portfolios:  112.7420999835631
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-10
# Combined Delta updated, new combined Delta is: 0.133
# Call Delta updated, new Call Delta is: 0.5679
# Put Delta updated, new Put Delta is: -0.4349
# Volatilities updated, new implied volatility for call option is: 0.17858
# Volatilities updated, new implied volatility for put option is: 0.21492
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  132.9753
# Long position is:  17905
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-11
# Value of Straddle position:  17833.77
# Value of the delta of the Straddle position:  0.13
# Value of the new short position according to BSM:  -23908.97
# Difference of the long positions:  72
# Difference of the short positions:  187
# A_0, total error, difference of the portfolios:  -259.07250202016075
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Combined Delta updated, new combined Delta is: 0.1823
# Call Delta updated, new Call Delta is: 0.595
# Put Delta updated, new Put Delta is: -0.4127
# Volatilities updated, new implied volatility for call option is: 0.17379
# Volatilities updated, new implied volatility for put option is: 0.20872
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  182.3127
# Long position is:  17834
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of Straddle position:  17445.22
# Value of the delta of the Straddle position:  0.18
# Value of the new short position according to BSM:  -32945.73
# Difference of the long positions:  389
# Difference of the short positions:  166
# A_0, total error, difference of the portfolios:  -554.4556247969267
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-12
# Combined Delta updated, new combined Delta is: 0.2168
# Call Delta updated, new Call Delta is: 0.6138
# Put Delta updated, new Put Delta is: -0.3971
# Volatilities updated, new implied volatility for call option is: 0.17276
# Volatilities updated, new implied volatility for put option is: 0.211
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  216.7747
# Long position is:  17445
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-13
# Value of Straddle position:  17071.98
# Value of the delta of the Straddle position:  0.22
# Value of the new short position according to BSM:  -38770.16
# Difference of the long positions:  373
# Difference of the short positions:  -403
# A_0, total error, difference of the portfolios:  29.958243834353198
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Combined Delta updated, new combined Delta is: 0.148
# Call Delta updated, new Call Delta is: 0.5766
# Put Delta updated, new Put Delta is: -0.4286
# Volatilities updated, new implied volatility for call option is: 0.18459
# Volatilities updated, new implied volatility for put option is: 0.22106
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  148.022
# Long position is:  17072
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of Straddle position:  17732.61
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -26454.5
# Difference of the long positions:  -661
# Difference of the short positions:  -19
# A_0, total error, difference of the portfolios:  679.8712316453348
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-16
# Combined Delta updated, new combined Delta is: 0.1368
# Call Delta updated, new Call Delta is: 0.5701
# Put Delta updated, new Put Delta is: -0.4333
# Volatilities updated, new implied volatility for call option is: 0.18375
# Volatilities updated, new implied volatility for put option is: 0.21305
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  136.8317
# Long position is:  17733
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-17
# Value of Straddle position:  17089.38
# Value of the delta of the Straddle position:  0.14
# Value of the new short position according to BSM:  -24239.73
# Difference of the long positions:  643
# Difference of the short positions:  -215
# A_0, total error, difference of the portfolios:  -428.40462478050904
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Combined Delta updated, new combined Delta is: 0.0786
# Call Delta updated, new Call Delta is: 0.5387
# Put Delta updated, new Put Delta is: -0.46
# Volatilities updated, new implied volatility for call option is: 0.1786
# Volatilities updated, new implied volatility for put option is: 0.21845
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  78.6232
# Long position is:  17089
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of Straddle position:  16941.38
# Value of the delta of the Straddle position:  0.08
# Value of the new short position according to BSM:  -13825.1
# Difference of the long positions:  148
# Difference of the short positions:  -103
# A_0, total error, difference of the portfolios:  -45.00090450752941
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-18
# Combined Delta updated, new combined Delta is: 0.0275
# Call Delta updated, new Call Delta is: 0.5103
# Put Delta updated, new Put Delta is: -0.4828
# Volatilities updated, new implied volatility for call option is: 0.18445
# Volatilities updated, new implied volatility for put option is: 0.22383
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  27.4899
# Long position is:  16941
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-19
# Value of Straddle position:  17321.68
# Value of the delta of the Straddle position:  0.03
# Value of the new short position according to BSM:  -4823.38
# Difference of the long positions:  -380
# Difference of the short positions:  -10
# A_0, total error, difference of the portfolios:  390.7518091687316
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Combined Delta updated, new combined Delta is: 0.0133
# Call Delta updated, new Call Delta is: 0.5025
# Put Delta updated, new Put Delta is: -0.4893
# Volatilities updated, new implied volatility for call option is: 0.1905
# Volatilities updated, new implied volatility for put option is: 0.22554
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  13.2756
# Long position is:  17322
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of Straddle position:  17648.38
# Value of the delta of the Straddle position:  0.01
# Value of the new short position according to BSM:  -2295.08
# Difference of the long positions:  -327
# Difference of the short positions:  -34
# A_0, total error, difference of the portfolios:  360.947070879859
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-20
# Combined Delta updated, new combined Delta is: -0.0824
# Call Delta updated, new Call Delta is: 0.4511
# Put Delta updated, new Put Delta is: -0.5336
# Volatilities updated, new implied volatility for call option is: 0.19215
# Volatilities updated, new implied volatility for put option is: 0.22685
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  82.4331
# Long position is:  17648
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-23
# Value of Straddle position:  17492.56
# Value of the delta of the Straddle position:  -0.08
# Value of the new short position according to BSM:  14260.92
# Difference of the long positions:  156
# Difference of the short positions:  -10
# A_0, total error, difference of the portfolios:  -145.92412538931967
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Combined Delta updated, new combined Delta is: -0.0837
# Call Delta updated, new Call Delta is: 0.4506
# Put Delta updated, new Put Delta is: -0.5343
# Volatilities updated, new implied volatility for call option is: 0.18823
# Volatilities updated, new implied volatility for put option is: 0.22921
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  83.6624
# Long position is:  17493
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of Straddle position:  17306.89
# Value of the delta of the Straddle position:  -0.08
# Value of the new short position according to BSM:  14510.4
# Difference of the long positions:  186
# Difference of the short positions:  -37
# A_0, total error, difference of the portfolios:  -148.86501478235368
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-24
# Combined Delta updated, new combined Delta is: -0.0708
# Call Delta updated, new Call Delta is: 0.4564
# Put Delta updated, new Put Delta is: -0.5271
# Volatilities updated, new implied volatility for call option is: 0.18458
# Volatilities updated, new implied volatility for put option is: 0.22108
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  70.7955
# Long position is:  17307
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-25
# Value of Straddle position:  17029.17
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12113.11
# Difference of the long positions:  278
# Difference of the short positions:  166
# A_0, total error, difference of the portfolios:  -443.38006546626457
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Combined Delta updated, new combined Delta is: -0.1687
# Call Delta updated, new Call Delta is: 0.404
# Put Delta updated, new Put Delta is: -0.5727
# Volatilities updated, new implied volatility for call option is: 0.19179
# Volatilities updated, new implied volatility for put option is: 0.22596
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  168.662
# Long position is:  17029
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of Straddle position:  18436.28
# Value of the delta of the Straddle position:  -0.17
# Value of the new short position according to BSM:  28148.0
# Difference of the long positions:  -1407
# Difference of the short positions:  710
# A_0, total error, difference of the portfolios:  697.042136108641
# =================================================
#
#
# =============== REHEDGE =========================
# ...
# =================================================
#
#
# =================================================
# Date: 2023-09-28
# Value of Straddle position:  18502.93
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18737.2
# Difference of the long positions:  98
# Difference of the short positions:  29
# A_0, total error, difference of the portfolios:  -126.68576476129601
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of Straddle position:  18373.09
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18794.29
# Difference of the long positions:  130
# Difference of the short positions:  57
# A_0, total error, difference of the portfolios:  -186.92030368612905
# =================================================
#
#
# =================================================
# Date: 2023-10-02
# Value of Straddle position:  17984.89
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19073.11
# Difference of the long positions:  388
# Difference of the short positions:  279
# A_0, total error, difference of the portfolios:  -667.0265255310878
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of Straddle position:  17971.68
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18924.92
# Difference of the long positions:  13
# Difference of the short positions:  -148
# A_0, total error, difference of the portfolios:  134.9807226367666
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Combined Delta updated, new combined Delta is: -0.0719
# Call Delta updated, new Call Delta is: 0.455
# Put Delta updated, new Put Delta is: -0.5269
# Volatilities updated, new implied volatility for call option is: 0.18955
# Volatilities updated, new implied volatility for put option is: 0.23255
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  71.9028
# Long position is:  17972
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of Straddle position:  19239.74
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12486.64
# Difference of the long positions:  -1268
# Difference of the short positions:  -91
# A_0, total error, difference of the portfolios:  1358.6621372800182
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of Straddle position:  19156.47
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12576.52
# Difference of the long positions:  83
# Difference of the short positions:  -90
# A_0, total error, difference of the portfolios:  6.606179127513315
# =================================================
#
#
# =================================================
# Date: 2023-10-06
# Value of Straddle position:  19233.48
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12762.03
# Difference of the long positions:  -77
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  262.51813069023774
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of Straddle position:  19149.45
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12869.88
# Difference of the long positions:  84
# Difference of the short positions:  -108
# A_0, total error, difference of the portfolios:  23.824149834670607
# =================================================
#
#
# =================================================
# Date: 2023-10-10
# Value of Straddle position:  18970.92
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12826.74
# Difference of the long positions:  179
# Difference of the short positions:  43
# A_0, total error, difference of the portfolios:  -221.67091813069965
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of Straddle position:  19093.73
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12928.12
# Difference of the long positions:  -123
# Difference of the short positions:  -101
# A_0, total error, difference of the portfolios:  224.19016145701607
# =================================================
#
#
# =================================================
# Date: 2023-10-12
# Value of Straddle position:  19172.38
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12993.55
# Difference of the long positions:  -79
# Difference of the short positions:  -65
# A_0, total error, difference of the portfolios:  144.08701173377267
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of Straddle position:  18749.98
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12859.82
# Difference of the long positions:  422
# Difference of the short positions:  134
# A_0, total error, difference of the portfolios:  -556.1410099464229
# =================================================
#
#
# =================================================
# Date: 2023-10-16
# Value of Straddle position:  18442.22
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12850.47
# Difference of the long positions:  308
# Difference of the short positions:  9
# A_0, total error, difference of the portfolios:  -317.10519556150393
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of Straddle position:  18176.38
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12737.58
# Difference of the long positions:  266
# Difference of the short positions:  113
# A_0, total error, difference of the portfolios:  -378.72703836684013
# =================================================
#
#
# =================================================
# Date: 2023-10-18
# Value of Straddle position:  18008.61
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12643.39
# Difference of the long positions:  168
# Difference of the short positions:  94
# A_0, total error, difference of the portfolios:  -261.96792760462995
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of Straddle position:  17906.2
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12616.07
# Difference of the long positions:  102
# Difference of the short positions:  27
# A_0, total error, difference of the portfolios:  -129.72673656157713
# =================================================
#
#
# =================================================
# Date: 2023-10-20
# Value of Straddle position:  17898.92
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12430.56
# Difference of the long positions:  7
# Difference of the short positions:  186
# A_0, total error, difference of the portfolios:  -192.79214989985667
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of Straddle position:  17619.41
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12439.18
# Difference of the long positions:  280
# Difference of the short positions:  -9
# A_0, total error, difference of the portfolios:  -270.8786484889388
# =================================================
#
#
# =================================================
# Date: 2023-10-24
# Value of Straddle position:  17495.98
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12470.82
# Difference of the long positions:  123
# Difference of the short positions:  -32
# A_0, total error, difference of the portfolios:  -91.79657176737237
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of Straddle position:  17672.19
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12302.57
# Difference of the long positions:  -176
# Difference of the short positions:  168
# A_0, total error, difference of the portfolios:  7.961325777245293
# =================================================
#
#
# =================================================
# Date: 2023-10-26
# Value of Straddle position:  18597.19
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11999.86
# Difference of the long positions:  -925
# Difference of the short positions:  303
# A_0, total error, difference of the portfolios:  622.2892089126872
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of Straddle position:  18129.36
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12095.49
# Difference of the long positions:  468
# Difference of the short positions:  -96
# A_0, total error, difference of the portfolios:  -372.203712704164
# =================================================
#
#
# =================================================
# Date: 2023-10-30
# Value of Straddle position:  17387.88
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12244.33
# Difference of the long positions:  741
# Difference of the short positions:  -149
# A_0, total error, difference of the portfolios:  -592.6366825203568
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of Straddle position:  17206.67
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12278.84
# Difference of the long positions:  181
# Difference of the short positions:  -35
# A_0, total error, difference of the portfolios:  -146.6949113831979
# =================================================
#
#
# =================================================
# Date: 2023-11-01
# Value of Straddle position:  16703.76
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12508.93
# Difference of the long positions:  503
# Difference of the short positions:  -230
# A_0, total error, difference of the portfolios:  -272.8249270230335
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of Straddle position:  16605.55
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12767.78
# Difference of the long positions:  98
# Difference of the short positions:  -259
# A_0, total error, difference of the portfolios:  160.63944751852796
# =================================================
#
#
# =================================================
# Date: 2023-11-03
# Value of Straddle position:  16454.7
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12701.63
# Difference of the long positions:  151
# Difference of the short positions:  66
# A_0, total error, difference of the portfolios:  -217.00167792851062
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of Straddle position:  16336.86
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12887.14
# Difference of the long positions:  118
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  67.66786924416556
# =================================================
#
#
# =================================================
# Date: 2023-11-07
# Value of Straddle position:  16682.11
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13073.37
# Difference of the long positions:  -345
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  531.4831084161779
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of Straddle position:  16830.17
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13150.3
# Difference of the long positions:  -148
# Difference of the short positions:  -77
# A_0, total error, difference of the portfolios:  224.9897180182943
# =================================================
#
#
# =================================================
# Date: 2023-11-09
# Value of Straddle position:  16591.45
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13115.79
# Difference of the long positions:  239
# Difference of the short positions:  35
# A_0, total error, difference of the portfolios:  -273.2255329191885
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of Straddle position:  17747.26
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13402.68
# Difference of the long positions:  -1156
# Difference of the short positions:  -287
# A_0, total error, difference of the portfolios:  1442.6931040277705
# =================================================
#
#
# =================================================
# Date: 2023-11-13
# Value of Straddle position:  16817.9
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13287.64
# Difference of the long positions:  929
# Difference of the short positions:  115
# A_0, total error, difference of the portfolios:  -1044.4008278149959
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of Straddle position:  17704.86
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13477.46
# Difference of the long positions:  -887
# Difference of the short positions:  -190
# A_0, total error, difference of the portfolios:  1076.7832890447862
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Combined Delta updated, new combined Delta is: 0.428
# Call Delta updated, new Call Delta is: 0.7298
# Put Delta updated, new Put Delta is: -0.3018
# Volatilities updated, new implied volatility for call option is: 0.146
# Volatilities updated, new implied volatility for put option is: 0.16729
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  428.0016
# Long position is:  17705
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of Straddle position:  14511.79
# Value of the delta of the Straddle position:  0.43
# Value of the new short position according to BSM:  -80468.58
# Difference of the long positions:  3193
# Difference of the short positions:  244
# A_0, total error, difference of the portfolios:  -3437.031310486698
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  266509.6714749044
# ==================================================

# %%
hedging_frequencies = [1, 2, 5, 10, 30]
results_dict = {'Frequency': [], 'Total_MSE': []}

for freq in hedging_frequencies:
    total_mean_squared_error, total_error = delta_hedge_straddle(df_result, freq)
    results_dict['Frequency'].append(freq)
    results_dict['Total_MSE'].append(total_error)

plt.plot(results_dict['Frequency'], results_dict['Total_MSE'], marker='o')
plt.xlabel('Hedging Frequency (days)')
plt.ylabel('Total Mean Squared Error')
plt.title('Total Mean Squared Error vs Hedging Frequency')
plt.show()
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of long Straddle portfolio:  21150.0
# Call delta:  0.5543
# Put delta:  -0.4446
# Delta of the Straddle (call delta + put delta):  0.1098
# Value of the short Straddle portfolio:  -19302.5368
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of Straddle position:  21260.57
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19455.12
# Difference of the long positions:  -111
# Difference of the short positions:  153
# A_0, total error, difference of the portfolios:  -42.01946813223549
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-22
# Combined Delta updated, new combined Delta is: 0.1501
# Call Delta updated, new Call Delta is: 0.5766
# Put Delta updated, new Put Delta is: -0.4265
# Volatilities updated, new implied volatility for call option is: 0.17638
# Volatilities updated, new implied volatility for put option is: 0.21344
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  150.1423
# Long position is:  21261
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-23
# Value of Straddle position:  21930.05
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -27193.78
# Difference of the long positions:  -669
# Difference of the short positions:  584
# A_0, total error, difference of the portfolios:  85.42868428560178
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Combined Delta updated, new combined Delta is: 0.2616
# Call Delta updated, new Call Delta is: 0.6374
# Put Delta updated, new Put Delta is: -0.3758
# Volatilities updated, new implied volatility for call option is: 0.17714
# Volatilities updated, new implied volatility for put option is: 0.21306
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  261.6367
# Long position is:  21930
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of Straddle position:  20963.63
# Value of the delta of the Straddle position:  0.26
# Value of the new short position according to BSM:  -46147.49
# Difference of the long positions:  966
# Difference of the short positions:  -1240
# A_0, total error, difference of the portfolios:  273.73947244342344
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-24
# Combined Delta updated, new combined Delta is: 0.1227
# Call Delta updated, new Call Delta is: 0.5615
# Put Delta updated, new Put Delta is: -0.4388
# Volatilities updated, new implied volatility for call option is: 0.18164
# Volatilities updated, new implied volatility for put option is: 0.21956
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  122.7186
# Long position is:  20964
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-25
# Value of Straddle position:  21823.3
# Value of the delta of the Straddle position:  0.12
# Value of the new short position according to BSM:  -21918.76
# Difference of the long positions:  -860
# Difference of the short positions:  274
# A_0, total error, difference of the portfolios:  586.004206039488
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Combined Delta updated, new combined Delta is: 0.1872
# Call Delta updated, new Call Delta is: 0.5967
# Put Delta updated, new Put Delta is: -0.4095
# Volatilities updated, new implied volatility for call option is: 0.17776
# Volatilities updated, new implied volatility for put option is: 0.2145
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  187.2166
# Long position is:  21823
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of Straddle position:  21459.51
# Value of the delta of the Straddle position:  0.19
# Value of the new short position according to BSM:  -33734.56
# Difference of the long positions:  364
# Difference of the short positions:  296
# A_0, total error, difference of the portfolios:  -659.5868106721755
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-28
# Combined Delta updated, new combined Delta is: 0.2321
# Call Delta updated, new Call Delta is: 0.6213
# Put Delta updated, new Put Delta is: -0.3892
# Volatilities updated, new implied volatility for call option is: 0.17576
# Volatilities updated, new implied volatility for put option is: 0.21055
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  232.1122
# Long position is:  21460
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-29
# Value of Straddle position:  22210.11
# Value of the delta of the Straddle position:  0.23
# Value of the new short position according to BSM:  -42736.5
# Difference of the long positions:  -751
# Difference of the short positions:  912
# A_0, total error, difference of the portfolios:  -161.60428949522247
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Combined Delta updated, new combined Delta is: 0.3439
# Call Delta updated, new Call Delta is: 0.6817
# Put Delta updated, new Put Delta is: -0.3378
# Volatilities updated, new implied volatility for call option is: 0.17367
# Volatilities updated, new implied volatility for put option is: 0.21022
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  343.8608
# Long position is:  22210
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of Straddle position:  23394.74
# Value of the delta of the Straddle position:  0.34
# Value of the new short position according to BSM:  -64525.48
# Difference of the long positions:  -1185
# Difference of the short positions:  1214
# A_0, total error, difference of the portfolios:  -29.196948776574573
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-30
# Combined Delta updated, new combined Delta is: 0.4376
# Call Delta updated, new Call Delta is: 0.7328
# Put Delta updated, new Put Delta is: -0.2952
# Volatilities updated, new implied volatility for call option is: 0.16913
# Volatilities updated, new implied volatility for put option is: 0.20868
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  437.6277
# Long position is:  23395
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-31
# Value of Straddle position:  23131.87
# Value of the delta of the Straddle position:  0.44
# Value of the new short position according to BSM:  -82217.11
# Difference of the long positions:  263
# Difference of the short positions:  96
# A_0, total error, difference of the portfolios:  -359.15026238892096
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Combined Delta updated, new combined Delta is: 0.4485
# Call Delta updated, new Call Delta is: 0.7402
# Put Delta updated, new Put Delta is: -0.2916
# Volatilities updated, new implied volatility for call option is: 0.17157
# Volatilities updated, new implied volatility for put option is: 0.20778
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  448.5445
# Long position is:  23132
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of Straddle position:  23857.67
# Value of the delta of the Straddle position:  0.45
# Value of the new short position according to BSM:  -84981.23
# Difference of the long positions:  -726
# Difference of the short positions:  713
# A_0, total error, difference of the portfolios:  12.620266738780629
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-01
# Combined Delta updated, new combined Delta is: 0.4857
# Call Delta updated, new Call Delta is: 0.7586
# Put Delta updated, new Put Delta is: -0.2729
# Volatilities updated, new implied volatility for call option is: 0.1665
# Volatilities updated, new implied volatility for put option is: 0.20595
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  485.653
# Long position is:  23858
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-05
# Value of Straddle position:  23373.26
# Value of the delta of the Straddle position:  0.49
# Value of the new short position according to BSM:  -92128.37
# Difference of the long positions:  484
# Difference of the short positions:  117
# A_0, total error, difference of the portfolios:  -600.9695775567525
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Combined Delta updated, new combined Delta is: 0.4997
# Call Delta updated, new Call Delta is: 0.7679
# Put Delta updated, new Put Delta is: -0.2683
# Volatilities updated, new implied volatility for call option is: 0.17039
# Volatilities updated, new implied volatility for put option is: 0.20944
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  499.6584
# Long position is:  23373
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of Straddle position:  20873.88
# Value of the delta of the Straddle position:  0.5
# Value of the new short position according to BSM:  -91392.52
# Difference of the long positions:  2499
# Difference of the short positions:  -3393
# A_0, total error, difference of the portfolios:  893.2961953827034
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-06
# Combined Delta updated, new combined Delta is: 0.3101
# Call Delta updated, new Call Delta is: 0.6649
# Put Delta updated, new Put Delta is: -0.3548
# Volatilities updated, new implied volatility for call option is: 0.17801
# Volatilities updated, new implied volatility for put option is: 0.21452
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  310.1311
# Long position is:  20874
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-07
# Value of Straddle position:  20220.09
# Value of the delta of the Straddle position:  0.31
# Value of the new short position according to BSM:  -55066.87
# Difference of the long positions:  654
# Difference of the short positions:  -1659
# A_0, total error, difference of the portfolios:  1005.4159066770044
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Combined Delta updated, new combined Delta is: 0.1428
# Call Delta updated, new Call Delta is: 0.5728
# Put Delta updated, new Put Delta is: -0.4299
# Volatilities updated, new implied volatility for call option is: 0.18514
# Volatilities updated, new implied volatility for put option is: 0.21781
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  142.844
# Long position is:  20220
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of Straddle position:  20766.05
# Value of the delta of the Straddle position:  0.14
# Value of the new short position according to BSM:  -25451.94
# Difference of the long positions:  -546
# Difference of the short positions:  89
# A_0, total error, difference of the portfolios:  457.3921531588021
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-08
# Combined Delta updated, new combined Delta is: 0.16
# Call Delta updated, new Call Delta is: 0.5817
# Put Delta updated, new Put Delta is: -0.4218
# Volatilities updated, new implied volatility for call option is: 0.17609
# Volatilities updated, new implied volatility for put option is: 0.21271
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  159.9538
# Long position is:  20766
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-11
# Value of Straddle position:  20031.29
# Value of the delta of the Straddle position:  0.16
# Value of the new short position according to BSM:  -28689.32
# Difference of the long positions:  735
# Difference of the short positions:  189
# A_0, total error, difference of the portfolios:  -923.5013289196759
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Combined Delta updated, new combined Delta is: 0.1961
# Call Delta updated, new Call Delta is: 0.602
# Put Delta updated, new Put Delta is: -0.4059
# Volatilities updated, new implied volatility for call option is: 0.17424
# Volatilities updated, new implied volatility for put option is: 0.20991
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  196.1313
# Long position is:  20031
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of Straddle position:  19272.84
# Value of the delta of the Straddle position:  0.2
# Value of the new short position according to BSM:  -34577.95
# Difference of the long positions:  758
# Difference of the short positions:  -600
# A_0, total error, difference of the portfolios:  -158.2889137948987
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-12
# Combined Delta updated, new combined Delta is: 0.0972
# Call Delta updated, new Call Delta is: 0.5481
# Put Delta updated, new Put Delta is: -0.4508
# Volatilities updated, new implied volatility for call option is: 0.16933
# Volatilities updated, new implied volatility for put option is: 0.20696
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  97.233
# Long position is:  19273
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-13
# Value of Straddle position:  18682.5
# Value of the delta of the Straddle position:  0.1
# Value of the new short position according to BSM:  -16938.96
# Difference of the long positions:  590
# Difference of the short positions:  -203
# A_0, total error, difference of the portfolios:  -387.1183049528263
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Combined Delta updated, new combined Delta is: 0.024
# Call Delta updated, new Call Delta is: 0.5078
# Put Delta updated, new Put Delta is: -0.4839
# Volatilities updated, new implied volatility for call option is: 0.16608
# Volatilities updated, new implied volatility for put option is: 0.20491
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  23.9702
# Long position is:  18683
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of Straddle position:  18424.56
# Value of the delta of the Straddle position:  0.02
# Value of the new short position according to BSM:  -4212.53
# Difference of the long positions:  258
# Difference of the short positions:  37
# A_0, total error, difference of the portfolios:  -294.6161599510242
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-14
# Combined Delta updated, new combined Delta is: 0.0746
# Call Delta updated, new Call Delta is: 0.5357
# Put Delta updated, new Put Delta is: -0.4611
# Volatilities updated, new implied volatility for call option is: 0.16432
# Volatilities updated, new implied volatility for put option is: 0.20274
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  74.5759
# Long position is:  18425
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-15
# Value of Straddle position:  18115.16
# Value of the delta of the Straddle position:  0.07
# Value of the new short position according to BSM:  -13051.53
# Difference of the long positions:  309
# Difference of the short positions:  -54
# A_0, total error, difference of the portfolios:  -254.96495811654313
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Combined Delta updated, new combined Delta is: 0.0473
# Call Delta updated, new Call Delta is: 0.5207
# Put Delta updated, new Put Delta is: -0.4734
# Volatilities updated, new implied volatility for call option is: 0.16719
# Volatilities updated, new implied volatility for put option is: 0.2093
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  47.307
# Long position is:  18115
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of Straddle position:  18646.69
# Value of the delta of the Straddle position:  0.05
# Value of the new short position according to BSM:  -8419.23
# Difference of the long positions:  -532
# Difference of the short positions:  140
# A_0, total error, difference of the portfolios:  391.5031530446322
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-18
# Combined Delta updated, new combined Delta is: 0.146
# Call Delta updated, new Call Delta is: 0.5753
# Put Delta updated, new Put Delta is: -0.4293
# Volatilities updated, new implied volatility for call option is: 0.16509
# Volatilities updated, new implied volatility for put option is: 0.20184
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  145.9885
# Long position is:  18647
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-19
# Value of Straddle position:  18286.65
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -26142.16
# Difference of the long positions:  360
# Difference of the short positions:  161
# A_0, total error, difference of the portfolios:  -520.6305687819913
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Combined Delta updated, new combined Delta is: 0.1838
# Call Delta updated, new Call Delta is: 0.596
# Put Delta updated, new Put Delta is: -0.4122
# Volatilities updated, new implied volatility for call option is: 0.16838
# Volatilities updated, new implied volatility for put option is: 0.20358
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  183.7539
# Long position is:  18287
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of Straddle position:  18023.74
# Value of the delta of the Straddle position:  0.18
# Value of the new short position according to BSM:  -32246.97
# Difference of the long positions:  263
# Difference of the short positions:  -658
# A_0, total error, difference of the portfolios:  394.93297500141125
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-20
# Combined Delta updated, new combined Delta is: 0.0575
# Call Delta updated, new Call Delta is: 0.5266
# Put Delta updated, new Put Delta is: -0.4691
# Volatilities updated, new implied volatility for call option is: 0.1732
# Volatilities updated, new implied volatility for put option is: 0.21005
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  57.5214
# Long position is:  18024
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-21
# Value of Straddle position:  18447.81
# Value of the delta of the Straddle position:  0.06
# Value of the new short position according to BSM:  -10004.7
# Difference of the long positions:  -424
# Difference of the short positions:  -90
# A_0, total error, difference of the portfolios:  513.80610323984
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Combined Delta updated, new combined Delta is: 0.0031
# Call Delta updated, new Call Delta is: 0.4966
# Put Delta updated, new Put Delta is: -0.4935
# Volatilities updated, new implied volatility for call option is: 0.17677
# Volatilities updated, new implied volatility for put option is: 0.21697
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  3.0519
# Long position is:  18448
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of Straddle position:  18891.96
# Value of the delta of the Straddle position:  0.0
# Value of the new short position according to BSM:  -533.44
# Difference of the long positions:  -444
# Difference of the short positions:  3
# A_0, total error, difference of the portfolios:  441.52115055258344
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-22
# Combined Delta updated, new combined Delta is: 0.0331
# Call Delta updated, new Call Delta is: 0.5128
# Put Delta updated, new Put Delta is: -0.4796
# Volatilities updated, new implied volatility for call option is: 0.18037
# Volatilities updated, new implied volatility for put option is: 0.21709
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  33.1381
# Long position is:  18892
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-25
# Value of Straddle position:  18902.3
# Value of the delta of the Straddle position:  0.03
# Value of the new short position according to BSM:  -5834.95
# Difference of the long positions:  -10
# Difference of the short positions:  43
# A_0, total error, difference of the portfolios:  -32.40232486757486
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Combined Delta updated, new combined Delta is: 0.0737
# Call Delta updated, new Call Delta is: 0.5353
# Put Delta updated, new Put Delta is: -0.4616
# Volatilities updated, new implied volatility for call option is: 0.17924
# Volatilities updated, new implied volatility for put option is: 0.2186
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  73.6501
# Long position is:  18902
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of Straddle position:  18834.37
# Value of the delta of the Straddle position:  0.07
# Value of the new short position according to BSM:  -12664.87
# Difference of the long positions:  68
# Difference of the short positions:  -303
# A_0, total error, difference of the portfolios:  235.50760422352505
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-26
# Combined Delta updated, new combined Delta is: -0.0698
# Call Delta updated, new Call Delta is: 0.4564
# Put Delta updated, new Put Delta is: -0.5262
# Volatilities updated, new implied volatility for call option is: 0.18641
# Volatilities updated, new implied volatility for put option is: 0.22476
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  69.7862
# Long position is:  18834
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-27
# Value of Straddle position:  19514.25
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11893.67
# Difference of the long positions:  -680
# Difference of the short positions:  107
# A_0, total error, difference of the portfolios:  573.1077573500042
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Combined Delta updated, new combined Delta is: -0.1175
# Call Delta updated, new Call Delta is: 0.4307
# Put Delta updated, new Put Delta is: -0.5482
# Volatilities updated, new implied volatility for call option is: 0.18271
# Volatilities updated, new implied volatility for put option is: 0.23031
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  117.5451
# Long position is:  19514
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of Straddle position:  19500.08
# Value of the delta of the Straddle position:  -0.12
# Value of the new short position according to BSM:  20063.77
# Difference of the long positions:  14
# Difference of the short positions:  -31
# A_0, total error, difference of the portfolios:  16.38455723815059
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-28
# Combined Delta updated, new combined Delta is: -0.1113
# Call Delta updated, new Call Delta is: 0.4317
# Put Delta updated, new Put Delta is: -0.543
# Volatilities updated, new implied volatility for call option is: 0.18038
# Volatilities updated, new implied volatility for put option is: 0.2238
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  111.2635
# Long position is:  19500
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-29
# Value of Straddle position:  18970.95
# Value of the delta of the Straddle position:  -0.11
# Value of the new short position according to BSM:  19049.43
# Difference of the long positions:  529
# Difference of the short positions:  -58
# A_0, total error, difference of the portfolios:  -471.2725775454892
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Combined Delta updated, new combined Delta is: -0.1
# Call Delta updated, new Call Delta is: 0.4389
# Put Delta updated, new Put Delta is: -0.5389
# Volatilities updated, new implied volatility for call option is: 0.17915
# Volatilities updated, new implied volatility for put option is: 0.22941
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  99.9923
# Long position is:  18971
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of Straddle position:  18787.88
# Value of the delta of the Straddle position:  -0.1
# Value of the new short position according to BSM:  17373.67
# Difference of the long positions:  183
# Difference of the short positions:  -254
# A_0, total error, difference of the portfolios:  70.91102111414511
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-02
# Combined Delta updated, new combined Delta is: -0.0158
# Call Delta updated, new Call Delta is: 0.4845
# Put Delta updated, new Put Delta is: -0.5003
# Volatilities updated, new implied volatility for call option is: 0.1793
# Volatilities updated, new implied volatility for put option is: 0.22185
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  15.783
# Long position is:  18788
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-03
# Value of Straddle position:  18429.51
# Value of the delta of the Straddle position:  -0.02
# Value of the new short position according to BSM:  2720.99
# Difference of the long positions:  358
# Difference of the short positions:  21
# A_0, total error, difference of the portfolios:  -379.67177010838805
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Combined Delta updated, new combined Delta is: -0.0675
# Call Delta updated, new Call Delta is: 0.4571
# Put Delta updated, new Put Delta is: -0.5246
# Volatilities updated, new implied volatility for call option is: 0.18955
# Volatilities updated, new implied volatility for put option is: 0.23255
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  67.5132
# Long position is:  18430
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of Straddle position:  19239.74
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11724.33
# Difference of the long positions:  -810
# Difference of the short positions:  -85
# A_0, total error, difference of the portfolios:  895.294695671957
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-04
# Combined Delta updated, new combined Delta is: -0.0184
# Call Delta updated, new Call Delta is: 0.4843
# Put Delta updated, new Put Delta is: -0.5027
# Volatilities updated, new implied volatility for call option is: 0.18718
# Volatilities updated, new implied volatility for put option is: 0.22297
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  18.4387
# Long position is:  19240
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-05
# Value of Straddle position:  18615.58
# Value of the delta of the Straddle position:  -0.02
# Value of the new short position according to BSM:  3225.11
# Difference of the long positions:  624
# Difference of the short positions:  -23
# A_0, total error, difference of the portfolios:  -601.1157417058662
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Combined Delta updated, new combined Delta is: 0.0195
# Call Delta updated, new Call Delta is: 0.506
# Put Delta updated, new Put Delta is: -0.4865
# Volatilities updated, new implied volatility for call option is: 0.18295
# Volatilities updated, new implied volatility for put option is: 0.22067
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  19.5057
# Long position is:  18616
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of Straddle position:  18395.91
# Value of the delta of the Straddle position:  0.02
# Value of the new short position according to BSM:  -3462.07
# Difference of the long positions:  220
# Difference of the short positions:  50
# A_0, total error, difference of the portfolios:  -269.9893204362511
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-06
# Combined Delta updated, new combined Delta is: 0.107
# Call Delta updated, new Call Delta is: 0.5537
# Put Delta updated, new Put Delta is: -0.4467
# Volatilities updated, new implied volatility for call option is: 0.17776
# Volatilities updated, new implied volatility for put option is: 0.21601
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  106.9938
# Long position is:  18396
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-09
# Value of Straddle position:  17885.86
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19150.82
# Difference of the long positions:  510
# Difference of the short positions:  160
# A_0, total error, difference of the portfolios:  -670.5429926115758
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Combined Delta updated, new combined Delta is: 0.1554
# Call Delta updated, new Call Delta is: 0.5804
# Put Delta updated, new Put Delta is: -0.425
# Volatilities updated, new implied volatility for call option is: 0.18158
# Volatilities updated, new implied volatility for put option is: 0.21655
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  155.4228
# Long position is:  17886
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of Straddle position:  17905.35
# Value of the delta of the Straddle position:  0.16
# Value of the new short position according to BSM:  -27725.87
# Difference of the long positions:  -19
# Difference of the short positions:  -93
# A_0, total error, difference of the portfolios:  112.7420999835631
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-10
# Combined Delta updated, new combined Delta is: 0.133
# Call Delta updated, new Call Delta is: 0.5679
# Put Delta updated, new Put Delta is: -0.4349
# Volatilities updated, new implied volatility for call option is: 0.17858
# Volatilities updated, new implied volatility for put option is: 0.21492
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  132.9753
# Long position is:  17905
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-11
# Value of Straddle position:  17833.77
# Value of the delta of the Straddle position:  0.13
# Value of the new short position according to BSM:  -23908.97
# Difference of the long positions:  72
# Difference of the short positions:  187
# A_0, total error, difference of the portfolios:  -259.07250202016075
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Combined Delta updated, new combined Delta is: 0.1823
# Call Delta updated, new Call Delta is: 0.595
# Put Delta updated, new Put Delta is: -0.4127
# Volatilities updated, new implied volatility for call option is: 0.17379
# Volatilities updated, new implied volatility for put option is: 0.20872
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  182.3127
# Long position is:  17834
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of Straddle position:  17445.22
# Value of the delta of the Straddle position:  0.18
# Value of the new short position according to BSM:  -32945.73
# Difference of the long positions:  389
# Difference of the short positions:  166
# A_0, total error, difference of the portfolios:  -554.4556247969267
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-12
# Combined Delta updated, new combined Delta is: 0.2168
# Call Delta updated, new Call Delta is: 0.6138
# Put Delta updated, new Put Delta is: -0.3971
# Volatilities updated, new implied volatility for call option is: 0.17276
# Volatilities updated, new implied volatility for put option is: 0.211
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  216.7747
# Long position is:  17445
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-13
# Value of Straddle position:  17071.98
# Value of the delta of the Straddle position:  0.22
# Value of the new short position according to BSM:  -38770.16
# Difference of the long positions:  373
# Difference of the short positions:  -403
# A_0, total error, difference of the portfolios:  29.958243834353198
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Combined Delta updated, new combined Delta is: 0.148
# Call Delta updated, new Call Delta is: 0.5766
# Put Delta updated, new Put Delta is: -0.4286
# Volatilities updated, new implied volatility for call option is: 0.18459
# Volatilities updated, new implied volatility for put option is: 0.22106
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  148.022
# Long position is:  17072
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of Straddle position:  17732.61
# Value of the delta of the Straddle position:  0.15
# Value of the new short position according to BSM:  -26454.5
# Difference of the long positions:  -661
# Difference of the short positions:  -19
# A_0, total error, difference of the portfolios:  679.8712316453348
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-16
# Combined Delta updated, new combined Delta is: 0.1368
# Call Delta updated, new Call Delta is: 0.5701
# Put Delta updated, new Put Delta is: -0.4333
# Volatilities updated, new implied volatility for call option is: 0.18375
# Volatilities updated, new implied volatility for put option is: 0.21305
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  136.8317
# Long position is:  17733
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-17
# Value of Straddle position:  17089.38
# Value of the delta of the Straddle position:  0.14
# Value of the new short position according to BSM:  -24239.73
# Difference of the long positions:  643
# Difference of the short positions:  -215
# A_0, total error, difference of the portfolios:  -428.40462478050904
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Combined Delta updated, new combined Delta is: 0.0786
# Call Delta updated, new Call Delta is: 0.5387
# Put Delta updated, new Put Delta is: -0.46
# Volatilities updated, new implied volatility for call option is: 0.1786
# Volatilities updated, new implied volatility for put option is: 0.21845
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  78.6232
# Long position is:  17089
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of Straddle position:  16941.38
# Value of the delta of the Straddle position:  0.08
# Value of the new short position according to BSM:  -13825.1
# Difference of the long positions:  148
# Difference of the short positions:  -103
# A_0, total error, difference of the portfolios:  -45.00090450752941
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-18
# Combined Delta updated, new combined Delta is: 0.0275
# Call Delta updated, new Call Delta is: 0.5103
# Put Delta updated, new Put Delta is: -0.4828
# Volatilities updated, new implied volatility for call option is: 0.18445
# Volatilities updated, new implied volatility for put option is: 0.22383
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  27.4899
# Long position is:  16941
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-19
# Value of Straddle position:  17321.68
# Value of the delta of the Straddle position:  0.03
# Value of the new short position according to BSM:  -4823.38
# Difference of the long positions:  -380
# Difference of the short positions:  -10
# A_0, total error, difference of the portfolios:  390.7518091687316
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Combined Delta updated, new combined Delta is: 0.0133
# Call Delta updated, new Call Delta is: 0.5025
# Put Delta updated, new Put Delta is: -0.4893
# Volatilities updated, new implied volatility for call option is: 0.1905
# Volatilities updated, new implied volatility for put option is: 0.22554
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  13.2756
# Long position is:  17322
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of Straddle position:  17648.38
# Value of the delta of the Straddle position:  0.01
# Value of the new short position according to BSM:  -2295.08
# Difference of the long positions:  -327
# Difference of the short positions:  -34
# A_0, total error, difference of the portfolios:  360.947070879859
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-20
# Combined Delta updated, new combined Delta is: -0.0824
# Call Delta updated, new Call Delta is: 0.4511
# Put Delta updated, new Put Delta is: -0.5336
# Volatilities updated, new implied volatility for call option is: 0.19215
# Volatilities updated, new implied volatility for put option is: 0.22685
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  82.4331
# Long position is:  17648
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-23
# Value of Straddle position:  17492.56
# Value of the delta of the Straddle position:  -0.08
# Value of the new short position according to BSM:  14260.92
# Difference of the long positions:  156
# Difference of the short positions:  -10
# A_0, total error, difference of the portfolios:  -145.92412538931967
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Combined Delta updated, new combined Delta is: -0.0837
# Call Delta updated, new Call Delta is: 0.4506
# Put Delta updated, new Put Delta is: -0.5343
# Volatilities updated, new implied volatility for call option is: 0.18823
# Volatilities updated, new implied volatility for put option is: 0.22921
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  83.6624
# Long position is:  17493
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of Straddle position:  17306.89
# Value of the delta of the Straddle position:  -0.08
# Value of the new short position according to BSM:  14510.4
# Difference of the long positions:  186
# Difference of the short positions:  -37
# A_0, total error, difference of the portfolios:  -148.86501478235368
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-24
# Combined Delta updated, new combined Delta is: -0.0708
# Call Delta updated, new Call Delta is: 0.4564
# Put Delta updated, new Put Delta is: -0.5271
# Volatilities updated, new implied volatility for call option is: 0.18458
# Volatilities updated, new implied volatility for put option is: 0.22108
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  70.7955
# Long position is:  17307
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-25
# Value of Straddle position:  17029.17
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12113.11
# Difference of the long positions:  278
# Difference of the short positions:  166
# A_0, total error, difference of the portfolios:  -443.38006546626457
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Combined Delta updated, new combined Delta is: -0.1687
# Call Delta updated, new Call Delta is: 0.404
# Put Delta updated, new Put Delta is: -0.5727
# Volatilities updated, new implied volatility for call option is: 0.19179
# Volatilities updated, new implied volatility for put option is: 0.22596
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  168.662
# Long position is:  17029
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of Straddle position:  18436.28
# Value of the delta of the Straddle position:  -0.17
# Value of the new short position according to BSM:  28148.0
# Difference of the long positions:  -1407
# Difference of the short positions:  710
# A_0, total error, difference of the portfolios:  697.042136108641
# =================================================
#
#
# =============== REHEDGE =========================
# ...
# =================================================
#
#
# =================================================
# Date: 2023-09-28
# Value of Straddle position:  18502.93
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18737.2
# Difference of the long positions:  98
# Difference of the short positions:  29
# A_0, total error, difference of the portfolios:  -126.68576476129601
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of Straddle position:  18373.09
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18794.29
# Difference of the long positions:  130
# Difference of the short positions:  57
# A_0, total error, difference of the portfolios:  -186.92030368612905
# =================================================
#
#
# =================================================
# Date: 2023-10-02
# Value of Straddle position:  17984.89
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -19073.11
# Difference of the long positions:  388
# Difference of the short positions:  279
# A_0, total error, difference of the portfolios:  -667.0265255310878
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of Straddle position:  17971.68
# Value of the delta of the Straddle position:  0.11
# Value of the new short position according to BSM:  -18924.92
# Difference of the long positions:  13
# Difference of the short positions:  -148
# A_0, total error, difference of the portfolios:  134.9807226367666
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Combined Delta updated, new combined Delta is: -0.0719
# Call Delta updated, new Call Delta is: 0.455
# Put Delta updated, new Put Delta is: -0.5269
# Volatilities updated, new implied volatility for call option is: 0.18955
# Volatilities updated, new implied volatility for put option is: 0.23255
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  71.9028
# Long position is:  17972
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of Straddle position:  19239.74
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12486.64
# Difference of the long positions:  -1268
# Difference of the short positions:  -91
# A_0, total error, difference of the portfolios:  1358.6621372800182
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of Straddle position:  19156.47
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12576.52
# Difference of the long positions:  83
# Difference of the short positions:  -90
# A_0, total error, difference of the portfolios:  6.606179127513315
# =================================================
#
#
# =================================================
# Date: 2023-10-06
# Value of Straddle position:  19233.48
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12762.03
# Difference of the long positions:  -77
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  262.51813069023774
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of Straddle position:  19149.45
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12869.88
# Difference of the long positions:  84
# Difference of the short positions:  -108
# A_0, total error, difference of the portfolios:  23.824149834670607
# =================================================
#
#
# =================================================
# Date: 2023-10-10
# Value of Straddle position:  18970.92
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12826.74
# Difference of the long positions:  179
# Difference of the short positions:  43
# A_0, total error, difference of the portfolios:  -221.67091813069965
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of Straddle position:  19093.73
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12928.12
# Difference of the long positions:  -123
# Difference of the short positions:  -101
# A_0, total error, difference of the portfolios:  224.19016145701607
# =================================================
#
#
# =================================================
# Date: 2023-10-12
# Value of Straddle position:  19172.38
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12993.55
# Difference of the long positions:  -79
# Difference of the short positions:  -65
# A_0, total error, difference of the portfolios:  144.08701173377267
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of Straddle position:  18749.98
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12859.82
# Difference of the long positions:  422
# Difference of the short positions:  134
# A_0, total error, difference of the portfolios:  -556.1410099464229
# =================================================
#
#
# =================================================
# Date: 2023-10-16
# Value of Straddle position:  18442.22
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12850.47
# Difference of the long positions:  308
# Difference of the short positions:  9
# A_0, total error, difference of the portfolios:  -317.10519556150393
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of Straddle position:  18176.38
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12737.58
# Difference of the long positions:  266
# Difference of the short positions:  113
# A_0, total error, difference of the portfolios:  -378.72703836684013
# =================================================
#
#
# =================================================
# Date: 2023-10-18
# Value of Straddle position:  18008.61
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12643.39
# Difference of the long positions:  168
# Difference of the short positions:  94
# A_0, total error, difference of the portfolios:  -261.96792760462995
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of Straddle position:  17906.2
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12616.07
# Difference of the long positions:  102
# Difference of the short positions:  27
# A_0, total error, difference of the portfolios:  -129.72673656157713
# =================================================
#
#
# =================================================
# Date: 2023-10-20
# Value of Straddle position:  17898.92
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12430.56
# Difference of the long positions:  7
# Difference of the short positions:  186
# A_0, total error, difference of the portfolios:  -192.79214989985667
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of Straddle position:  17619.41
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12439.18
# Difference of the long positions:  280
# Difference of the short positions:  -9
# A_0, total error, difference of the portfolios:  -270.8786484889388
# =================================================
#
#
# =================================================
# Date: 2023-10-24
# Value of Straddle position:  17495.98
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12470.82
# Difference of the long positions:  123
# Difference of the short positions:  -32
# A_0, total error, difference of the portfolios:  -91.79657176737237
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of Straddle position:  17672.19
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12302.57
# Difference of the long positions:  -176
# Difference of the short positions:  168
# A_0, total error, difference of the portfolios:  7.961325777245293
# =================================================
#
#
# =================================================
# Date: 2023-10-26
# Value of Straddle position:  18597.19
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  11999.86
# Difference of the long positions:  -925
# Difference of the short positions:  303
# A_0, total error, difference of the portfolios:  622.2892089126872
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of Straddle position:  18129.36
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12095.49
# Difference of the long positions:  468
# Difference of the short positions:  -96
# A_0, total error, difference of the portfolios:  -372.203712704164
# =================================================
#
#
# =================================================
# Date: 2023-10-30
# Value of Straddle position:  17387.88
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12244.33
# Difference of the long positions:  741
# Difference of the short positions:  -149
# A_0, total error, difference of the portfolios:  -592.6366825203568
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of Straddle position:  17206.67
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12278.84
# Difference of the long positions:  181
# Difference of the short positions:  -35
# A_0, total error, difference of the portfolios:  -146.6949113831979
# =================================================
#
#
# =================================================
# Date: 2023-11-01
# Value of Straddle position:  16703.76
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12508.93
# Difference of the long positions:  503
# Difference of the short positions:  -230
# A_0, total error, difference of the portfolios:  -272.8249270230335
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of Straddle position:  16605.55
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12767.78
# Difference of the long positions:  98
# Difference of the short positions:  -259
# A_0, total error, difference of the portfolios:  160.63944751852796
# =================================================
#
#
# =================================================
# Date: 2023-11-03
# Value of Straddle position:  16454.7
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12701.63
# Difference of the long positions:  151
# Difference of the short positions:  66
# A_0, total error, difference of the portfolios:  -217.00167792851062
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of Straddle position:  16336.86
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  12887.14
# Difference of the long positions:  118
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  67.66786924416556
# =================================================
#
#
# =================================================
# Date: 2023-11-07
# Value of Straddle position:  16682.11
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13073.37
# Difference of the long positions:  -345
# Difference of the short positions:  -186
# A_0, total error, difference of the portfolios:  531.4831084161779
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of Straddle position:  16830.17
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13150.3
# Difference of the long positions:  -148
# Difference of the short positions:  -77
# A_0, total error, difference of the portfolios:  224.9897180182943
# =================================================
#
#
# =================================================
# Date: 2023-11-09
# Value of Straddle position:  16591.45
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13115.79
# Difference of the long positions:  239
# Difference of the short positions:  35
# A_0, total error, difference of the portfolios:  -273.2255329191885
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of Straddle position:  17747.26
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13402.68
# Difference of the long positions:  -1156
# Difference of the short positions:  -287
# A_0, total error, difference of the portfolios:  1442.6931040277705
# =================================================
#
#
# =================================================
# Date: 2023-11-13
# Value of Straddle position:  16817.9
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13287.64
# Difference of the long positions:  929
# Difference of the short positions:  115
# A_0, total error, difference of the portfolios:  -1044.4008278149959
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of Straddle position:  17704.86
# Value of the delta of the Straddle position:  -0.07
# Value of the new short position according to BSM:  13477.46
# Difference of the long positions:  -887
# Difference of the short positions:  -190
# A_0, total error, difference of the portfolios:  1076.7832890447862
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Combined Delta updated, new combined Delta is: 0.428
# Call Delta updated, new Call Delta is: 0.7298
# Put Delta updated, new Put Delta is: -0.3018
# Volatilities updated, new implied volatility for call option is: 0.146
# Volatilities updated, new implied volatility for put option is: 0.16729
# To delta-hedge the Straddle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  428.0016
# Long position is:  17705
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of Straddle position:  14511.79
# Value of the delta of the Straddle position:  0.43
# Value of the new short position according to BSM:  -80468.58
# Difference of the long positions:  3193
# Difference of the short positions:  244
# A_0, total error, difference of the portfolios:  -3437.031310486698
# =================================================
#
#
# ========== Total Mean Squared Error ==============
# The total mean squared error is :  266509.6714749044
# ==================================================

# %% [markdown]
# # Delta hedging a strangle option strategy

# %% [markdown]
# Strangle is another option strategy, which involves purchasing or selling two options of the same underlying. In a Strangle an investor buys a put and a call of the same underlying with the same maturities, but this time the strike prices will be different. The way to make profit is the same as in Strangle, that the investor expects the market to be volatile and move sharp to some direction, either up or down. The difference to Straddle is that the stock price has to move farther in Strangle to make profit.
#
# In our long strangle, we buy an OTM call and an OTM put.

# %%
# TODO: Copy-paste spaghetti, refactor when time
# - Give stuff as parameter instead of declaring the in the function
# - Printing to its own function/module
def delta_hedge_strangle(option_prices):
    # Apple stock is sold in 1000 pcs units
    # Lets assume that the amount is same for put and call options
    # Not sure if they can be different, like 800 puts and 1000 calls
    option_amount = 1000

    # 3-Month Treasury Yield taken on a daily basis regarding our hedging interval
    interest_rate = option_prices.iloc[0]['Interest rate']
    stock_price = option_prices.iloc[0]['Underlying']

    # Adjust here the call and put prices for your liking
    # STRANGLE = Same option, same maturities, but both call and put which have different strikes
    call_option_price = option_prices.iloc[0]['C180']
    put_option_price = option_prices.iloc[0]['P175']
    put_strike = 175
    call_strike = 180
    
    time_to_maturity = option_prices.iloc[0]['T']
    call_volatility = implied_volatility(price=call_option_price, S=stock_price, K=call_strike, t=time_to_maturity, r=interest_rate, flag='c')
    put_volatility = implied_volatility(price=put_option_price, S=stock_price, K=put_strike, t=time_to_maturity, r=interest_rate, flag='p')
    
    # Initial stuff at t = 0
    call_bsm = BSM(kind='call', S0=stock_price, K=call_strike, T=time_to_maturity, r=interest_rate, sigma=call_volatility)
    put_bsm = BSM(kind='put', S0=stock_price, K=put_strike, T=time_to_maturity, r=interest_rate, sigma=put_volatility)

    # Forming the straddle portfolio
    put_delta = put_bsm.delta()
    call_delta = call_bsm.delta()

    # Long position consists of both of the option values
    OP = call_bsm.value() * option_amount + put_bsm.value() * option_amount

    # Short position, the replicating protfolio, consists of the call and put delta amounts of the underlying 
    RE = - call_delta * stock_price * option_amount + put_delta * stock_price * option_amount

    # Combined delta of the options
    combined_delta = call_delta + put_delta

    print("================ Initial values: =================")
    print("Date:", option_prices.iloc[0]['Date'])
    print("Value of long Straddle portfolio: ", round(OP, 4))
    print('Call delta: ', round(call_delta, 4))
    print('Put delta: ', round(put_delta, 4))
    print("Value of the delta of the Strangle (call delta + put delta): ", round(combined_delta, 4))
    print("Value of the short Strangle portfolio: ", round(RE, 4))
    print('==================================================')
    print('\n')

    # Keep track of the mean squared error values, which means changes in the portfolios
    # This corresponds to the do we make loss or profit in hedging
    total_mean_squared_error = []
    
    # Next we calculate changes in OP and RE and let A_0 = d OP - d RE
    # Hedge as long as there are dates in the dataframe
    for i in range(1, len(option_prices)-1):
        new_call_bsm_obj = BSM(kind='call', S0=option_prices['Underlying'][i], K=call_strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=call_volatility)
        new_put_bsm_obj = BSM(kind='put', S0=option_prices['Underlying'][i], K=put_strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=put_volatility)
        new_OP = new_call_bsm_obj.value() * option_amount + new_put_bsm_obj.value() * option_amount
        new_RE = -combined_delta * option_prices['Underlying'][i] * option_amount
        d_OP = new_OP - OP
        d_RE = combined_delta * (option_prices['Underlying'][i+1] - option_prices['Underlying'][i]) * option_amount
        a_0 = d_OP - d_RE
        total_mean_squared_error.append(a_0**2)

        print('=================================================')
        print("Date:", option_prices['Date'][i])
        print("Value of Strangle position: ", round(new_OP, 2))
        print("Value of the delta of the Strangle position: ", round(combined_delta, 2))
        print("Value of the new short position according to BSM: ", round(new_RE, 2))
        print("Difference of the long positions: ", round(OP - new_OP))
        print("Difference of the short positions: ", round(RE - new_RE))
        print("A_0, total error, difference of the portfolios: ", a_0)
        print('=================================================')
        print('\n')

        OP = new_OP
        RE = new_RE

        # Rehedging happens here
        # every second day, t2, t4, t6, so on..
        # Change the modulo for different intervals, 1 = every day, 30 = every month and so on
        # Delta and volatility will be updated when we rehedge
        # As time goes by, the stock price moves/changes. This will affect the delta of the stock option, delta of the underlying is always 1
        # In a real world scenario this hedging costs money, and will be simulated if we have time also in this
        if i % 2 == 0:
            put_delta = new_put_bsm_obj.delta()
            call_delta= new_call_bsm_obj.delta()
            combined_delta =  put_delta + call_delta
            call_volatility = BSM(kind='call', S0=option_prices['Underlying'][i], K=call_strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=call_volatility).implied_vol(option_prices['C180'][i])
            put_volatility = BSM(kind='put', S0=option_prices['Underlying'][i], K=put_strike, T=option_prices['T'][i], r=option_prices['Interest rate'][i], sigma=put_volatility).implied_vol(option_prices['P175'][i])

            print('=============== REHEDGE =========================')
            print("Rehedging date:", option_prices['Date'][i])
            print("Combined Delta updated, new combined Delta is:", round(combined_delta, 4))
            print("Call Delta updated, new Call Delta is:", round(call_delta, 4))
            print("Put Delta updated, new Put Delta is:", round(put_delta, 4))
            print("Volatilities updated, new implied volatility for call option is:", round(call_volatility, 5))
            print("Volatilities updated, new implied volatility for put option is:", round(put_volatility, 5))
            print('To delta-hedge the Strangle position, we need to readjust the RE:')
            
            # We have to solve a linear equation, where the delta of the portfolio is zero
            # And we have to readjust by shorting delta amount of the underlying
            # Delta of the underlying is always 1
            RE = -combined_delta * option_prices['Underlying'][i] * option_amount
            
            # 1 = for the amount of options
            amount = -(combined_delta * option_amount)
            if amount > 0:
                print('Readjusting replicating portoflio RE, amount options to buy to balance the portfolio: ', round(amount, 4))
            elif amount < 0:
                print('Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio: ', round(-amount, 4))
            else:
                print('Portfolio is in balance, no need for readjustment')
            print('Long position is: ', round(OP))
            print('=============== REHEDGE ENDS ====================')
            print('\n')
        
    # Count the total error
    # Determines did we make profit or loss
    total_error = 0
    for i in range(0, len(total_mean_squared_error)-1):
        total_error += total_mean_squared_error[i]
    total_error = total_error*(1/(len(total_mean_squared_error)-1))
    print('========== Total Mean Squared Error ==============')
    print("The total mean squared error is : ", total_error)
    print('==================================================')

# %%
delta_hedge_strangle(df_result)
# Out:
# ================ Initial values: =================
# Date: 2023-08-21
# Value of long Straddle portfolio:  18950.0
# Call delta:  0.5543
# Put delta:  -0.3795
# Value of the delta of the Strangle (call delta + put delta):  0.1748
# Value of the short Strangle portfolio:  -164214.0518
# ==================================================
#
#
# =================================================
# Date: 2023-08-22
# Value of Strangle position:  19148.73
# Value of the delta of the Strangle position:  0.17
# Value of the new short position according to BSM:  -30979.62
# Difference of the long positions:  -199
# Difference of the short positions:  -133234
# A_0, total error, difference of the portfolios:  -481.2385096935652
# =================================================
#
#
# =================================================
# Date: 2023-08-23
# Value of Strangle position:  20122.2
# Value of the delta of the Strangle position:  0.17
# Value of the new short position according to BSM:  -31659.59
# Difference of the long positions:  -973
# Difference of the short positions:  680
# A_0, total error, difference of the portfolios:  1802.0219315543984
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-23
# Combined Delta updated, new combined Delta is: 0.3229
# Call Delta updated, new Call Delta is: 0.638
# Put Delta updated, new Put Delta is: -0.315
# Volatilities updated, new implied volatility for call option is: 0.17714
# Volatilities updated, new implied volatility for put option is: 0.2166
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  322.9339
# Long position is:  20122
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-24
# Value of Strangle position:  18871.19
# Value of the delta of the Strangle position:  0.32
# Value of the new short position according to BSM:  -56959.08
# Difference of the long positions:  1251
# Difference of the short positions:  -1531
# A_0, total error, difference of the portfolios:  -1971.1582655544098
# =================================================
#
#
# =================================================
# Date: 2023-08-25
# Value of Strangle position:  19294.06
# Value of the delta of the Strangle position:  0.32
# Value of the new short position according to BSM:  -57679.22
# Difference of the long positions:  -423
# Difference of the short positions:  720
# A_0, total error, difference of the portfolios:  -87.35974771773499
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-25
# Combined Delta updated, new combined Delta is: 0.2532
# Call Delta updated, new Call Delta is: 0.5977
# Put Delta updated, new Put Delta is: -0.3445
# Volatilities updated, new implied volatility for call option is: 0.17776
# Volatilities updated, new implied volatility for put option is: 0.21706
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  253.1868
# Long position is:  19294
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-28
# Value of Strangle position:  19556.79
# Value of the delta of the Strangle position:  0.25
# Value of the new short position according to BSM:  -45621.73
# Difference of the long positions:  -263
# Difference of the short positions:  400
# A_0, total error, difference of the portfolios:  -732.2935453363527
# =================================================
#
#
# =================================================
# Date: 2023-08-29
# Value of Strangle position:  20847.4
# Value of the delta of the Strangle position:  0.25
# Value of the new short position according to BSM:  -46616.76
# Difference of the long positions:  -1291
# Difference of the short positions:  995
# A_0, total error, difference of the portfolios:  396.85553123803504
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-29
# Combined Delta updated, new combined Delta is: 0.4004
# Call Delta updated, new Call Delta is: 0.6803
# Put Delta updated, new Put Delta is: -0.28
# Volatilities updated, new implied volatility for call option is: 0.17367
# Volatilities updated, new implied volatility for put option is: 0.21287
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  400.3712
# Long position is:  20847
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-08-30
# Value of Strangle position:  21960.6
# Value of the delta of the Strangle position:  0.4
# Value of the new short position according to BSM:  -75129.65
# Difference of the long positions:  -1113
# Difference of the short positions:  1413
# A_0, total error, difference of the portfolios:  1025.1143918565463
# =================================================
#
#
# =================================================
# Date: 2023-08-31
# Value of Strangle position:  21993.31
# Value of the delta of the Strangle position:  0.4
# Value of the new short position according to BSM:  -75217.73
# Difference of the long positions:  -33
# Difference of the short positions:  88
# A_0, total error, difference of the portfolios:  -603.8714545475895
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-08-31
# Combined Delta updated, new combined Delta is: 0.4994
# Call Delta updated, new Call Delta is: 0.7358
# Put Delta updated, new Put Delta is: -0.2364
# Volatilities updated, new implied volatility for call option is: 0.17157
# Volatilities updated, new implied volatility for put option is: 0.21295
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  499.3551
# Long position is:  21993
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-01
# Value of Strangle position:  22641.92
# Value of the delta of the Strangle position:  0.5
# Value of the new short position according to BSM:  -94607.82
# Difference of the long positions:  -649
# Difference of the short positions:  794
# A_0, total error, difference of the portfolios:  528.7609366634849
# =================================================
#
#
# =================================================
# Date: 2023-09-05
# Value of Strangle position:  22475.06
# Value of the delta of the Strangle position:  0.5
# Value of the new short position according to BSM:  -94727.67
# Difference of the long positions:  167
# Difference of the short positions:  120
# A_0, total error, difference of the portfolios:  3223.762628007064
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-05
# Combined Delta updated, new combined Delta is: 0.5456
# Call Delta updated, new Call Delta is: 0.7624
# Put Delta updated, new Put Delta is: -0.2169
# Volatilities updated, new implied volatility for call option is: 0.17039
# Volatilities updated, new implied volatility for put option is: 0.21601
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  545.565
# Long position is:  22475
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-06
# Value of Strangle position:  19339.04
# Value of the delta of the Strangle position:  0.55
# Value of the new short position according to BSM:  -99789.29
# Difference of the long positions:  3136
# Difference of the short positions:  -3704
# A_0, total error, difference of the portfolios:  -217.2444747847494
# =================================================
#
#
# =================================================
# Date: 2023-09-07
# Value of Strangle position:  17688.88
# Value of the delta of the Strangle position:  0.55
# Value of the new short position according to BSM:  -96870.52
# Difference of the long positions:  1650
# Difference of the short positions:  -2919
# A_0, total error, difference of the portfolios:  -1988.4183270927126
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-07
# Combined Delta updated, new combined Delta is: 0.2126
# Call Delta updated, new Call Delta is: 0.5738
# Put Delta updated, new Put Delta is: -0.3612
# Volatilities updated, new implied volatility for call option is: 0.18514
# Volatilities updated, new implied volatility for put option is: 0.21996
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  212.5673
# Long position is:  17689
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-08
# Value of Strangle position:  18687.1
# Value of the delta of the Strangle position:  0.21
# Value of the new short position according to BSM:  -37875.24
# Difference of the long positions:  -998
# Difference of the short positions:  132
# A_0, total error, difference of the portfolios:  747.3896064121826
# =================================================
#
#
# =================================================
# Date: 2023-09-11
# Value of Strangle position:  18734.09
# Value of the delta of the Strangle position:  0.21
# Value of the new short position according to BSM:  -38126.06
# Difference of the long positions:  -47
# Difference of the short positions:  251
# A_0, total error, difference of the portfolios:  697.4508462228976
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-11
# Combined Delta updated, new combined Delta is: 0.26
# Call Delta updated, new Call Delta is: 0.5996
# Put Delta updated, new Put Delta is: -0.3395
# Volatilities updated, new implied volatility for call option is: 0.17424
# Volatilities updated, new implied volatility for put option is: 0.21312
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  260.0476
# Long position is:  18734
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-12
# Value of Strangle position:  17125.15
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -45846.39
# Difference of the long positions:  1609
# Difference of the short positions:  -796
# A_0, total error, difference of the portfolios:  -1065.4375150217456
# =================================================
#
#
# =================================================
# Date: 2023-09-13
# Value of Strangle position:  16768.31
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -45302.89
# Difference of the long positions:  357
# Difference of the short positions:  -543
# A_0, total error, difference of the portfolios:  -754.7177924172038
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-13
# Combined Delta updated, new combined Delta is: 0.0996
# Call Delta updated, new Call Delta is: 0.509
# Put Delta updated, new Put Delta is: -0.4094
# Volatilities updated, new implied volatility for call option is: 0.16608
# Volatilities updated, new implied volatility for put option is: 0.2091
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  99.5885
# Long position is:  16768
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-14
# Value of Strangle position:  16286.51
# Value of the delta of the Strangle position:  0.1
# Value of the new short position according to BSM:  -17501.69
# Difference of the long positions:  482
# Difference of the short positions:  152
# A_0, total error, difference of the portfolios:  -409.1034685101937
# =================================================
#
#
# =================================================
# Date: 2023-09-15
# Value of Strangle position:  16113.78
# Value of the delta of the Strangle position:  0.1
# Value of the new short position according to BSM:  -17428.99
# Difference of the long positions:  173
# Difference of the short positions:  -73
# A_0, total error, difference of the portfolios:  -467.5041139584277
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-15
# Combined Delta updated, new combined Delta is: 0.1234
# Call Delta updated, new Call Delta is: 0.521
# Put Delta updated, new Put Delta is: -0.3976
# Volatilities updated, new implied volatility for call option is: 0.16719
# Volatilities updated, new implied volatility for put option is: 0.2085
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  123.4167
# Long position is:  16114
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-18
# Value of Strangle position:  16422.44
# Value of the delta of the Strangle position:  0.12
# Value of the new short position according to BSM:  -21964.47
# Difference of the long positions:  -309
# Difference of the short positions:  365
# A_0, total error, difference of the portfolios:  172.8946161910967
# =================================================
#
#
# =================================================
# Date: 2023-09-19
# Value of Strangle position:  16606.38
# Value of the delta of the Strangle position:  0.12
# Value of the new short position according to BSM:  -22100.23
# Difference of the long positions:  -184
# Difference of the short positions:  136
# A_0, total error, difference of the portfolios:  625.7797256472609
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-19
# Combined Delta updated, new combined Delta is: 0.2557
# Call Delta updated, new Call Delta is: 0.5953
# Put Delta updated, new Put Delta is: -0.3396
# Volatilities updated, new implied volatility for call option is: 0.16838
# Volatilities updated, new implied volatility for put option is: 0.2071
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  255.7312
# Long position is:  16606
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-20
# Value of Strangle position:  15822.55
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -44878.26
# Difference of the long positions:  784
# Difference of the short positions:  -916
# A_0, total error, difference of the portfolios:  -384.89077591085214
# =================================================
#
#
# =================================================
# Date: 2023-09-21
# Value of Strangle position:  15581.07
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -44479.32
# Difference of the long positions:  241
# Difference of the short positions:  -399
# A_0, total error, difference of the portfolios:  -461.4144983290679
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-21
# Combined Delta updated, new combined Delta is: 0.0789
# Call Delta updated, new Call Delta is: 0.4952
# Put Delta updated, new Put Delta is: -0.4163
# Volatilities updated, new implied volatility for call option is: 0.17677
# Volatilities updated, new implied volatility for put option is: 0.21601
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  78.8968
# Long position is:  15581
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-22
# Value of Strangle position:  16403.25
# Value of the delta of the Strangle position:  0.08
# Value of the new short position according to BSM:  -13790.37
# Difference of the long positions:  -822
# Difference of the short positions:  68
# A_0, total error, difference of the portfolios:  720.4019041009352
# =================================================
#
#
# =================================================
# Date: 2023-09-25
# Value of Strangle position:  16330.43
# Value of the delta of the Strangle position:  0.08
# Value of the new short position according to BSM:  -13892.14
# Difference of the long positions:  73
# Difference of the short positions:  102
# A_0, total error, difference of the portfolios:  252.2369578895587
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-25
# Combined Delta updated, new combined Delta is: 0.1485
# Call Delta updated, new Call Delta is: 0.535
# Put Delta updated, new Put Delta is: -0.3865
# Volatilities updated, new implied volatility for call option is: 0.17924
# Volatilities updated, new implied volatility for put option is: 0.22568
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  148.4559
# Long position is:  16330
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-26
# Value of Strangle position:  16492.51
# Value of the delta of the Strangle position:  0.15
# Value of the new short position according to BSM:  -25528.47
# Difference of the long positions:  -162
# Difference of the short positions:  -612
# A_0, total error, difference of the portfolios:  389.2230798854215
# =================================================
#
#
# =================================================
# Date: 2023-09-27
# Value of Strangle position:  16447.66
# Value of the delta of the Strangle position:  0.15
# Value of the new short position according to BSM:  -25301.33
# Difference of the long positions:  45
# Difference of the short positions:  -227
# A_0, total error, difference of the portfolios:  -83.45000084571313
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-27
# Combined Delta updated, new combined Delta is: -0.0479
# Call Delta updated, new Call Delta is: 0.426
# Put Delta updated, new Put Delta is: -0.4739
# Volatilities updated, new implied volatility for call option is: 0.18271
# Volatilities updated, new implied volatility for put option is: 0.22822
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  47.8735
# Long position is:  16448
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-09-28
# Value of Strangle position:  16634.43
# Value of the delta of the Strangle position:  -0.05
# Value of the new short position according to BSM:  8171.53
# Difference of the long positions:  -187
# Difference of the short positions:  -12
# A_0, total error, difference of the portfolios:  211.66596217250498
# =================================================
#
#
# =================================================
# Date: 2023-09-29
# Value of Strangle position:  16540.55
# Value of the delta of the Strangle position:  -0.05
# Value of the new short position according to BSM:  8196.42
# Difference of the long positions:  94
# Difference of the short positions:  -25
# A_0, total error, difference of the portfolios:  27.714257176044086
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-09-29
# Combined Delta updated, new combined Delta is: -0.0229
# Call Delta updated, new Call Delta is: 0.4403
# Put Delta updated, new Put Delta is: -0.4633
# Volatilities updated, new implied volatility for call option is: 0.17915
# Volatilities updated, new implied volatility for put option is: 0.2227
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  22.9349
# Long position is:  16541
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-02
# Value of Strangle position:  15932.08
# Value of the delta of the Strangle position:  -0.02
# Value of the new short position according to BSM:  3984.94
# Difference of the long positions:  608
# Difference of the short positions:  -58
# A_0, total error, difference of the portfolios:  -639.4303095976546
# =================================================
#
#
# =================================================
# Date: 2023-10-03
# Value of Strangle position:  15804.81
# Value of the delta of the Strangle position:  -0.02
# Value of the new short position according to BSM:  3953.98
# Difference of the long positions:  127
# Difference of the short positions:  31
# A_0, total error, difference of the portfolios:  -98.37688075775992
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-03
# Combined Delta updated, new combined Delta is: 0.0096
# Call Delta updated, new Call Delta is: 0.4571
# Put Delta updated, new Put Delta is: -0.4474
# Volatilities updated, new implied volatility for call option is: 0.18955
# Volatilities updated, new implied volatility for put option is: 0.23165
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  9.6481
# Long position is:  15805
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-04
# Value of Strangle position:  16629.38
# Value of the delta of the Strangle position:  0.01
# Value of the new short position according to BSM:  -1675.48
# Difference of the long positions:  -825
# Difference of the short positions:  12
# A_0, total error, difference of the portfolios:  812.5176367477973
# =================================================
#
#
# =================================================
# Date: 2023-10-05
# Value of Strangle position:  16636.26
# Value of the delta of the Strangle position:  0.01
# Value of the new short position according to BSM:  -1687.54
# Difference of the long positions:  -7
# Difference of the short positions:  12
# A_0, total error, difference of the portfolios:  -18.02020647315438
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-05
# Combined Delta updated, new combined Delta is: 0.0958
# Call Delta updated, new Call Delta is: 0.5065
# Put Delta updated, new Put Delta is: -0.4107
# Volatilities updated, new implied volatility for call option is: 0.18295
# Volatilities updated, new implied volatility for put option is: 0.22559
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  95.7869
# Long position is:  16636
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-06
# Value of Strangle position:  16340.83
# Value of the delta of the Strangle position:  0.1
# Value of the new short position according to BSM:  -17001.21
# Difference of the long positions:  295
# Difference of the short positions:  247
# A_0, total error, difference of the portfolios:  -439.1059483196001
# =================================================
#
#
# =================================================
# Date: 2023-10-09
# Value of Strangle position:  16373.35
# Value of the delta of the Strangle position:  0.1
# Value of the new short position according to BSM:  -17144.89
# Difference of the long positions:  -33
# Difference of the short positions:  144
# A_0, total error, difference of the portfolios:  89.98752703334745
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-09
# Combined Delta updated, new combined Delta is: 0.2287
# Call Delta updated, new Call Delta is: 0.5794
# Put Delta updated, new Put Delta is: -0.3507
# Volatilities updated, new implied volatility for call option is: 0.18158
# Volatilities updated, new implied volatility for put option is: 0.22007
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  228.7088
# Long position is:  16373
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-10
# Value of Strangle position:  15858.77
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -40799.37
# Difference of the long positions:  515
# Difference of the short positions:  -137
# A_0, total error, difference of the portfolios:  -837.0539603651162
# =================================================
#
#
# =================================================
# Date: 2023-10-11
# Value of Strangle position:  16097.66
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -41121.85
# Difference of the long positions:  -239
# Difference of the short positions:  322
# A_0, total error, difference of the portfolios:  30.764081007278747
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-11
# Combined Delta updated, new combined Delta is: 0.2576
# Call Delta updated, new Call Delta is: 0.5942
# Put Delta updated, new Put Delta is: -0.3365
# Volatilities updated, new implied volatility for call option is: 0.17379
# Volatilities updated, new implied volatility for put option is: 0.21144
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  257.6326
# Long position is:  16098
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-12
# Value of Strangle position:  15566.88
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -46556.78
# Difference of the long positions:  531
# Difference of the short positions:  234
# A_0, total error, difference of the portfolios:  -51.58511337879497
# =================================================
#
#
# =================================================
# Date: 2023-10-13
# Value of Strangle position:  14989.14
# Value of the delta of the Strangle position:  0.26
# Value of the new short position according to BSM:  -46077.58
# Difference of the long positions:  578
# Difference of the short positions:  -479
# A_0, total error, difference of the portfolios:  -544.2426834601947
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-13
# Combined Delta updated, new combined Delta is: 0.2294
# Call Delta updated, new Call Delta is: 0.5764
# Put Delta updated, new Put Delta is: -0.347
# Volatilities updated, new implied volatility for call option is: 0.18459
# Volatilities updated, new implied volatility for put option is: 0.22449
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  229.4421
# Long position is:  14989
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-16
# Value of Strangle position:  15687.35
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -41005.9
# Difference of the long positions:  -698
# Difference of the short positions:  -30
# A_0, total error, difference of the portfolios:  1058.431131552251
# =================================================
#
#
# =================================================
# Date: 2023-10-17
# Value of Strangle position:  15299.03
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -40645.68
# Difference of the long positions:  388
# Difference of the short positions:  -360
# A_0, total error, difference of the portfolios:  -87.75587614742466
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-17
# Combined Delta updated, new combined Delta is: 0.1595
# Call Delta updated, new Call Delta is: 0.5387
# Put Delta updated, new Put Delta is: -0.3792
# Volatilities updated, new implied volatility for call option is: 0.1786
# Volatilities updated, new implied volatility for put option is: 0.22227
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  159.4575
# Long position is:  15299
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-18
# Value of Strangle position:  14680.69
# Value of the delta of the Strangle position:  0.16
# Value of the new short position according to BSM:  -28039.01
# Difference of the long positions:  618
# Difference of the short positions:  -209
# A_0, total error, difference of the portfolios:  -557.7421830997056
# =================================================
#
#
# =================================================
# Date: 2023-10-19
# Value of Strangle position:  14550.44
# Value of the delta of the Strangle position:  0.16
# Value of the new short position according to BSM:  -27978.42
# Difference of the long positions:  130
# Difference of the short positions:  -61
# A_0, total error, difference of the portfolios:  281.15413406968395
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-19
# Combined Delta updated, new combined Delta is: 0.0944
# Call Delta updated, new Call Delta is: 0.5012
# Put Delta updated, new Put Delta is: -0.4067
# Volatilities updated, new implied volatility for call option is: 0.1905
# Volatilities updated, new implied volatility for put option is: 0.22825
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  94.4397
# Long position is:  14550
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-20
# Value of Strangle position:  15081.96
# Value of the delta of the Strangle position:  0.09
# Value of the new short position according to BSM:  -16326.73
# Difference of the long positions:  -532
# Difference of the short positions:  -244
# A_0, total error, difference of the portfolios:  520.1854263399669
# =================================================
#
#
# =================================================
# Date: 2023-10-23
# Value of Strangle position:  14804.81
# Value of the delta of the Strangle position:  0.09
# Value of the new short position according to BSM:  -16338.06
# Difference of the long positions:  277
# Difference of the short positions:  11
# A_0, total error, difference of the portfolios:  -318.7055143339008
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-23
# Combined Delta updated, new combined Delta is: -0.0008
# Call Delta updated, new Call Delta is: 0.4498
# Put Delta updated, new Put Delta is: -0.4506
# Volatilities updated, new implied volatility for call option is: 0.18823
# Volatilities updated, new implied volatility for put option is: 0.23015
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  0.7805
# Long position is:  14805
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-24
# Value of Strangle position:  14699.23
# Value of the delta of the Strangle position:  -0.0
# Value of the new short position according to BSM:  135.38
# Difference of the long positions:  106
# Difference of the short positions:  0
# A_0, total error, difference of the portfolios:  -107.40588846554131
# =================================================
#
#
# =================================================
# Date: 2023-10-25
# Value of Strangle position:  14682.76
# Value of the delta of the Strangle position:  -0.0
# Value of the new short position according to BSM:  133.55
# Difference of the long positions:  16
# Difference of the short positions:  2
# A_0, total error, difference of the portfolios:  -19.761085559499787
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-25
# Combined Delta updated, new combined Delta is: -0.0779
# Call Delta updated, new Call Delta is: 0.4067
# Put Delta updated, new Put Delta is: -0.4846
# Volatilities updated, new implied volatility for call option is: 0.19179
# Volatilities updated, new implied volatility for put option is: 0.23089
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  77.8877
# Long position is:  14683
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-26
# Value of Strangle position:  15419.35
# Value of the delta of the Strangle position:  -0.08
# Value of the new short position according to BSM:  12998.67
# Difference of the long positions:  -737
# Difference of the short positions:  328
# A_0, total error, difference of the portfolios:  840.1800896638478
# =================================================
#
#
# =================================================
# Date: 2023-10-27
# Value of Strangle position:  15055.36
# Value of the delta of the Strangle position:  -0.08
# Value of the new short position according to BSM:  13102.26
# Difference of the long positions:  364
# Difference of the short positions:  -104
# A_0, total error, difference of the portfolios:  -202.75782813221338
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-27
# Combined Delta updated, new combined Delta is: -0.189
# Call Delta updated, new Call Delta is: 0.3479
# Put Delta updated, new Put Delta is: -0.5369
# Volatilities updated, new implied volatility for call option is: 0.1918
# Volatilities updated, new implied volatility for put option is: 0.2411
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  189.018
# Long position is:  15055
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-10-30
# Value of Strangle position:  14866.61
# Value of the delta of the Strangle position:  -0.19
# Value of the new short position according to BSM:  32187.88
# Difference of the long positions:  189
# Difference of the short positions:  -391
# A_0, total error, difference of the portfolios:  -98.01912564124734
# =================================================
#
#
# =================================================
# Date: 2023-10-31
# Value of Strangle position:  14720.21
# Value of the delta of the Strangle position:  -0.19
# Value of the new short position according to BSM:  32278.61
# Difference of the long positions:  146
# Difference of the short positions:  -91
# A_0, total error, difference of the portfolios:  458.4524891364705
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-10-31
# Combined Delta updated, new combined Delta is: -0.1007
# Call Delta updated, new Call Delta is: 0.3929
# Put Delta updated, new Put Delta is: -0.4936
# Volatilities updated, new implied volatility for call option is: 0.18301
# Volatilities updated, new implied volatility for put option is: 0.22297
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to buy to balance the portfolio:  100.6847
# Long position is:  14720
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-01
# Value of Strangle position:  13454.63
# Value of the delta of the Strangle position:  -0.1
# Value of the new short position according to BSM:  17516.12
# Difference of the long positions:  1266
# Difference of the short positions:  -322
# A_0, total error, difference of the portfolios:  -903.1099917488808
# =================================================
#
#
# =================================================
# Date: 2023-11-02
# Value of Strangle position:  13665.07
# Value of the delta of the Strangle position:  -0.1
# Value of the new short position according to BSM:  17878.58
# Difference of the long positions:  -210
# Difference of the short positions:  -362
# A_0, total error, difference of the portfolios:  117.80397653183725
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-02
# Combined Delta updated, new combined Delta is: 0.1567
# Call Delta updated, new Call Delta is: 0.533
# Put Delta updated, new Put Delta is: -0.3763
# Volatilities updated, new implied volatility for call option is: 0.17615
# Volatilities updated, new implied volatility for put option is: 0.21133
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  156.7198
# Long position is:  13665
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-03
# Value of Strangle position:  12731.97
# Value of the delta of the Strangle position:  0.16
# Value of the new short position according to BSM:  -27684.56
# Difference of the long positions:  933
# Difference of the short positions:  -144
# A_0, total error, difference of the portfolios:  -1337.4364887846762
# =================================================
#
#
# =================================================
# Date: 2023-11-06
# Value of Strangle position:  12878.96
# Value of the delta of the Strangle position:  0.16
# Value of the new short position according to BSM:  -28088.9
# Difference of the long positions:  -147
# Difference of the short positions:  404
# A_0, total error, difference of the portfolios:  -258.90748645380455
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-06
# Combined Delta updated, new combined Delta is: 0.2252
# Call Delta updated, new Call Delta is: 0.5677
# Put Delta updated, new Put Delta is: -0.3425
# Volatilities updated, new implied volatility for call option is: 0.15078
# Volatilities updated, new implied volatility for put option is: 0.18445
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  225.1504
# Long position is:  12879
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-07
# Value of Strangle position:  11659.8
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -40936.84
# Difference of the long positions:  1219
# Difference of the short positions:  583
# A_0, total error, difference of the portfolios:  -1460.0699460910384
# =================================================
#
#
# =================================================
# Date: 2023-11-08
# Value of Strangle position:  11982.86
# Value of the delta of the Strangle position:  0.23
# Value of the new short position according to BSM:  -41177.75
# Difference of the long positions:  -323
# Difference of the short positions:  241
# A_0, total error, difference of the portfolios:  431.124105748224
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-08
# Combined Delta updated, new combined Delta is: 0.4102
# Call Delta updated, new Call Delta is: 0.6667
# Put Delta updated, new Put Delta is: -0.2565
# Volatilities updated, new implied volatility for call option is: 0.1492
# Volatilities updated, new implied volatility for put option is: 0.18297
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  410.2012
# Long position is:  11983
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-09
# Value of Strangle position:  11594.18
# Value of the delta of the Strangle position:  0.41
# Value of the new short position according to BSM:  -74824.8
# Difference of the long positions:  389
# Difference of the short positions:  -197
# A_0, total error, difference of the portfolios:  -2025.3800934744131
# =================================================
#
#
# =================================================
# Date: 2023-11-10
# Value of Strangle position:  13400.85
# Value of the delta of the Strangle position:  0.41
# Value of the new short position according to BSM:  -76461.51
# Difference of the long positions:  -1807
# Difference of the short positions:  1637
# A_0, total error, difference of the portfolios:  2462.992175837236
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-10
# Combined Delta updated, new combined Delta is: 0.555
# Call Delta updated, new Call Delta is: 0.7502
# Put Delta updated, new Put Delta is: -0.1952
# Volatilities updated, new implied volatility for call option is: 0.14943
# Volatilities updated, new implied volatility for put option is: 0.18082
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  554.9611
# Long position is:  13401
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-13
# Value of Strangle position:  12240.95
# Value of the delta of the Strangle position:  0.55
# Value of the new short position according to BSM:  -102556.81
# Difference of the long positions:  1160
# Difference of the short positions:  -888
# A_0, total error, difference of the portfolios:  -2624.9989658710992
# =================================================
#
#
# =================================================
# Date: 2023-11-14
# Value of Strangle position:  13602.02
# Value of the delta of the Strangle position:  0.55
# Value of the new short position according to BSM:  -104021.9
# Difference of the long positions:  -1361
# Difference of the short positions:  1465
# A_0, total error, difference of the portfolios:  1044.7408971984714
# =================================================
#
#
# =============== REHEDGE =========================
# Rehedging date: 2023-11-14
# Combined Delta updated, new combined Delta is: 0.6013
# Call Delta updated, new Call Delta is: 0.7744
# Put Delta updated, new Put Delta is: -0.1731
# Volatilities updated, new implied volatility for call option is: 0.146
# Volatilities updated, new implied volatility for put option is: nan
# To delta-hedge the Strangle position, we need to readjust the RE:
# Readjusting replicating portoflio RE, amount options to short/sell to balance the portfolio:  601.2724
# Long position is:  13602
# =============== REHEDGE ENDS ====================
#
#
# =================================================
# Date: 2023-11-15
# Value of Strangle position:  nan
# Value of the delta of the Strangle position:  0.6
# Value of the new short position according to BSM:  -113045.22
# /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages/pyfinance/options.py:151: RuntimeWarning: overflow encountered in scalar power
#   + (self.r + 0.5 * self.sigma ** 2) * self.T
# /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages/pyfinance/options.py:242: RuntimeWarning: divide by zero encountered in scalar divide
#   vol = vol + diff / opt.vega()
# /Users/aleksi/koodaus/hedging-simulation/venv/lib/python3.9/site-packages/pyfinance/options.py:149: RuntimeWarning: invalid value encountered in scalar divide
#   self.d1 = (
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 delta_hedge_strangle(df_result)
#
# Cell In[10], line 73, in delta_hedge_strangle(option_prices)
#      71 print("Value of the delta of the Strangle position: ", round(combined_delta, 2))
#      72 print("Value of the new short position according to BSM: ", round(new_RE, 2))
# ---> 73 print("Difference of the long positions: ", round(OP - new_OP))
#      74 print("Difference of the short positions: ", round(RE - new_RE))
#      75 print("A_0, total error, difference of the portfolios: ", a_0)
#
# ValueError: cannot convert float NaN to integer
